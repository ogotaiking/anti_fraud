# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns


import numpy as np
import pandas as pd
import tensorflow as tf

import atecml.data
import atecml.fs

from contextlib import contextmanager
from tqdm import tqdm
from time import strftime,time
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import joblib
from concurrent.futures import ProcessPoolExecutor

plt.style.use('ggplot')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#训练集为过滤掉所有unknown标签的
num_cat = 32


train_df= atecml.data.load_train()
train_df.loc[train_df.label == 0, 'Fraud'] = 0
train_df.loc[train_df.label == 1, 'Fraud'] = 1
target ='Fraud'


predictors = [x for x in train_df.columns if x not in atecml.data.NOT_FEATURE_COLUMNS]


#F5可能是一个地域标签，聚类分组一下
train_df['f5'] =train_df['f5']//100

# %%
iv_list = {}
woe_table = {}
type_list = {}

nan_result = atecml.data.calc_iv(df=train_df,feature='NaN_LIST',target=target,category_num=64)        
niv = nan_result[0]
nwoe_df = nan_result[1]
nfeature_type = nan_result[2]
iv_list.update(niv)
woe_table.update(nwoe_df)
type_list.update(nfeature_type)

def mt_iv(feature):
    return atecml.data.calc_iv(df=train_df,feature=feature,target=target,category_num=num_cat)

with ProcessPoolExecutor(max_workers=40) as pool:
    for pool_result in pool.map(mt_iv,predictors):
        iv = pool_result[0]
        woe_df = pool_result[1]
        feature_type = pool_result[2]
        iv_list.update(iv)
        woe_table.update(woe_df)
        type_list.update(feature_type)
# Out:
# [2018-07-05 18:03:28][WoE/IV Calculation for NaN_LIST] Begin ...
# [2018-07-05 18:04:25][WoE/IV Calculation for NaN_LIST] End   ...[Elapsed: 56.36s]
# [2018-07-05 18:04:28][WoE/IV Calculation for f8] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f22] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f6] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f2] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f9] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f1] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f10] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f5] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f7] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f13] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f3] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f4] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f14] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f11] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f12] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f15] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f16] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f19] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f21] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f18] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f17] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f20] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f23] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f24] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f26] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f25] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f28] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f31] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f29] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f27] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f30] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f32] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f33] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f34] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f38] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f40] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f35] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f36] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f37] Begin ...
# [2018-07-05 18:04:28][WoE/IV Calculation for f39] Begin ...
# [2018-07-05 18:05:14][WoE/IV Calculation for f36] End   ...[Elapsed: 45.54s]
# [2018-07-05 18:05:14][WoE/IV Calculation for f41] Begin ...
# [2018-07-05 18:05:16][WoE/IV Calculation for f27] End   ...[Elapsed: 48.04s]
# [2018-07-05 18:05:16][WoE/IV Calculation for f42] Begin ...
# [2018-07-05 18:05:20][WoE/IV Calculation for f37] End   ...[Elapsed: 52.35s]
# [2018-07-05 18:05:20][WoE/IV Calculation for f43] Begin ...
# [2018-07-05 18:05:22][WoE/IV Calculation for f4] End   ...[Elapsed: 53.56s]
# [2018-07-05 18:05:22][WoE/IV Calculation for f44] Begin ...
# [2018-07-05 18:05:23][WoE/IV Calculation for f30] End   ...[Elapsed: 54.65s]
# [2018-07-05 18:05:23][WoE/IV Calculation for f45] Begin ...
# [2018-07-05 18:05:25][WoE/IV Calculation for f15] End   ...[Elapsed: 56.76s]
# [2018-07-05 18:05:25][WoE/IV Calculation for f46] Begin ...
# [2018-07-05 18:05:25][WoE/IV Calculation for f19] End   ...[Elapsed: 57.53s]
# [2018-07-05 18:05:26][WoE/IV Calculation for f47] Begin ...
# [2018-07-05 18:05:28][WoE/IV Calculation for f17] End   ...[Elapsed: 59.73s]
# [2018-07-05 18:05:28][WoE/IV Calculation for f48] Begin ...
# [2018-07-05 18:05:28][WoE/IV Calculation for f16] End   ...[Elapsed: 59.73s]
# [2018-07-05 18:05:28][WoE/IV Calculation for f49] Begin ...
# [2018-07-05 18:05:29][WoE/IV Calculation for f2] End   ...[Elapsed: 60.65s]
# [2018-07-05 18:05:29][WoE/IV Calculation for f50] Begin ...
# [2018-07-05 18:05:29][WoE/IV Calculation for f25] End   ...[Elapsed: 61.07s]
# [2018-07-05 18:05:29][WoE/IV Calculation for f51] Begin ...
# [2018-07-05 18:05:29][WoE/IV Calculation for f28] End   ...[Elapsed: 61.18s]
# [2018-07-05 18:05:29][WoE/IV Calculation for f52] Begin ...
# [2018-07-05 18:05:30][WoE/IV Calculation for f26] End   ...[Elapsed: 62.13s]
# [2018-07-05 18:05:30][WoE/IV Calculation for f53] Begin ...
# [2018-07-05 18:05:32][WoE/IV Calculation for f24] End   ...[Elapsed: 63.89s]
# [2018-07-05 18:05:32][WoE/IV Calculation for f54] Begin ...
# [2018-07-05 18:05:34][WoE/IV Calculation for f23] End   ...[Elapsed: 65.58s]
# [2018-07-05 18:05:34][WoE/IV Calculation for f55] Begin ...
# [2018-07-05 18:05:35][WoE/IV Calculation for f40] End   ...[Elapsed: 66.56s]
# [2018-07-05 18:05:35][WoE/IV Calculation for f56] Begin ...
# [2018-07-05 18:05:39][WoE/IV Calculation for f39] End   ...[Elapsed: 71.15s]
# [2018-07-05 18:05:39][WoE/IV Calculation for f57] Begin ...
# [2018-07-05 18:05:39][WoE/IV Calculation for f29] End   ...[Elapsed: 71.26s]
# [2018-07-05 18:05:39][WoE/IV Calculation for f58] Begin ...
# [2018-07-05 18:05:40][WoE/IV Calculation for f21] End   ...[Elapsed: 72.07s]
# [2018-07-05 18:05:40][WoE/IV Calculation for f59] Begin ...
# [2018-07-05 18:05:40][WoE/IV Calculation for f22] End   ...[Elapsed: 72.35s]
# [2018-07-05 18:05:40][WoE/IV Calculation for f60] Begin ...
# [2018-07-05 18:05:42][WoE/IV Calculation for f31] End   ...[Elapsed: 74.05s]
# [2018-07-05 18:05:42][WoE/IV Calculation for f61] Begin ...
# [2018-07-05 18:05:42][WoE/IV Calculation for f38] End   ...[Elapsed: 74.05s]
# [2018-07-05 18:05:42][WoE/IV Calculation for f62] Begin ...
# [2018-07-05 18:05:42][WoE/IV Calculation for f5] End   ...[Elapsed: 74.48s]
# [2018-07-05 18:05:42][WoE/IV Calculation for f63] Begin ...
# [2018-07-05 18:05:43][WoE/IV Calculation for f9] End   ...[Elapsed: 75.39s]
# [2018-07-05 18:05:43][WoE/IV Calculation for f64] Begin ...
# [2018-07-05 18:05:45][WoE/IV Calculation for f10] End   ...[Elapsed: 76.90s]
# [2018-07-05 18:05:45][WoE/IV Calculation for f65] Begin ...
# [2018-07-05 18:05:45][WoE/IV Calculation for f8] End   ...[Elapsed: 77.53s]
# [2018-07-05 18:05:46][WoE/IV Calculation for f66] Begin ...
# [2018-07-05 18:05:48][WoE/IV Calculation for f12] End   ...[Elapsed: 80.46s]
# [2018-07-05 18:05:48][WoE/IV Calculation for f67] Begin ...
# [2018-07-05 18:05:49][WoE/IV Calculation for f41] End   ...[Elapsed: 35.65s]
# [2018-07-05 18:05:49][WoE/IV Calculation for f68] Begin ...
# [2018-07-05 18:05:49][WoE/IV Calculation for f20] End   ...[Elapsed: 81.38s]
# [2018-07-05 18:05:49][WoE/IV Calculation for f69] Begin ...
# [2018-07-05 18:05:50][WoE/IV Calculation for f13] End   ...[Elapsed: 81.87s]
# [2018-07-05 18:05:50][WoE/IV Calculation for f70] Begin ...
# [2018-07-05 18:05:53][WoE/IV Calculation for f35] End   ...[Elapsed: 85.07s]
# [2018-07-05 18:05:53][WoE/IV Calculation for f71] Begin ...
# [2018-07-05 18:05:54][WoE/IV Calculation for f18] End   ...[Elapsed: 85.59s]
# [2018-07-05 18:05:54][WoE/IV Calculation for f72] Begin ...
# [2018-07-05 18:05:55][WoE/IV Calculation for f3] End   ...[Elapsed: 86.66s]
# [2018-07-05 18:05:55][WoE/IV Calculation for f73] Begin ...
# [2018-07-05 18:05:55][WoE/IV Calculation for f11] End   ...[Elapsed: 86.79s]
# [2018-07-05 18:05:55][WoE/IV Calculation for f74] Begin ...
# [2018-07-05 18:05:55][WoE/IV Calculation for f45] End   ...[Elapsed: 32.66s]
# [2018-07-05 18:05:55][WoE/IV Calculation for f75] Begin ...
# [2018-07-05 18:05:55][WoE/IV Calculation for f1] End   ...[Elapsed: 87.47s]
# [2018-07-05 18:05:55][WoE/IV Calculation for f76] Begin ...
# [2018-07-05 18:05:57][WoE/IV Calculation for f43] End   ...[Elapsed: 36.78s]
# [2018-07-05 18:05:57][WoE/IV Calculation for f77] Begin ...
# [2018-07-05 18:05:58][WoE/IV Calculation for f6] End   ...[Elapsed: 89.58s]
# [2018-07-05 18:05:58][WoE/IV Calculation for f78] Begin ...
# [2018-07-05 18:06:01][WoE/IV Calculation for f42] End   ...[Elapsed: 44.70s]
# [2018-07-05 18:06:01][WoE/IV Calculation for f79] Begin ...
# [2018-07-05 18:06:03][WoE/IV Calculation for f34] End   ...[Elapsed: 95.04s]
# [2018-07-05 18:06:03][WoE/IV Calculation for f80] Begin ...
# [2018-07-05 18:06:04][WoE/IV Calculation for f32] End   ...[Elapsed: 95.75s]
# [2018-07-05 18:06:04][WoE/IV Calculation for f81] Begin ...
# [2018-07-05 18:06:04][WoE/IV Calculation for f14] End   ...[Elapsed: 95.93s]
# [2018-07-05 18:06:04][WoE/IV Calculation for f82] Begin ...
# [2018-07-05 18:06:06][WoE/IV Calculation for f33] End   ...[Elapsed: 97.67s]
# [2018-07-05 18:06:06][WoE/IV Calculation for f83] Begin ...
# [2018-07-05 18:06:08][WoE/IV Calculation for f46] End   ...[Elapsed: 42.79s]
# [2018-07-05 18:06:08][WoE/IV Calculation for f84] Begin ...
# [2018-07-05 18:06:09][WoE/IV Calculation for f47] End   ...[Elapsed: 42.99s]
# [2018-07-05 18:06:09][WoE/IV Calculation for f85] Begin ...
# [2018-07-05 18:06:11][WoE/IV Calculation for f49] End   ...[Elapsed: 43.37s]
# [2018-07-05 18:06:11][WoE/IV Calculation for f86] Begin ...
# [2018-07-05 18:06:13][WoE/IV Calculation for f56] End   ...[Elapsed: 38.34s]
# [2018-07-05 18:06:13][WoE/IV Calculation for f87] Begin ...
# [2018-07-05 18:06:18][WoE/IV Calculation for f57] End   ...[Elapsed: 38.88s]
# [2018-07-05 18:06:18][WoE/IV Calculation for f88] Begin ...
# [2018-07-05 18:06:23][WoE/IV Calculation for f68] End   ...[Elapsed: 34.29s]
# [2018-07-05 18:06:23][WoE/IV Calculation for f89] Begin ...
# [2018-07-05 18:06:24][WoE/IV Calculation for f52] End   ...[Elapsed: 55.13s]
# [2018-07-05 18:06:24][WoE/IV Calculation for f90] Begin ...
# [2018-07-05 18:06:27][WoE/IV Calculation for f64] End   ...[Elapsed: 43.89s]
# [2018-07-05 18:06:27][WoE/IV Calculation for f91] Begin ...
# [2018-07-05 18:06:30][WoE/IV Calculation for f48] End   ...[Elapsed: 62.16s]
# [2018-07-05 18:06:30][WoE/IV Calculation for f92] Begin ...
# [2018-07-05 18:06:30][WoE/IV Calculation for f61] End   ...[Elapsed: 47.94s]
# [2018-07-05 18:06:30][WoE/IV Calculation for f93] Begin ...
# [2018-07-05 18:06:32][WoE/IV Calculation for f75] End   ...[Elapsed: 36.86s]
# [2018-07-05 18:06:32][WoE/IV Calculation for f94] Begin ...
# [2018-07-05 18:06:33][WoE/IV Calculation for f7] End   ...[Elapsed: 124.85s]
# [2018-07-05 18:06:33][WoE/IV Calculation for f95] Begin ...
# [2018-07-05 18:06:34][WoE/IV Calculation for f58] End   ...[Elapsed: 54.30s]
# [2018-07-05 18:06:34][WoE/IV Calculation for f96] Begin ...
# [2018-07-05 18:06:34][WoE/IV Calculation for f51] End   ...[Elapsed: 64.82s]
# [2018-07-05 18:06:34][WoE/IV Calculation for f97] Begin ...
# [2018-07-05 18:06:34][WoE/IV Calculation for f62] End   ...[Elapsed: 51.92s]
# [2018-07-05 18:06:34][WoE/IV Calculation for f98] Begin ...
# [2018-07-05 18:06:36][WoE/IV Calculation for f53] End   ...[Elapsed: 66.26s]
# [2018-07-05 18:06:36][WoE/IV Calculation for f99] Begin ...
# [2018-07-05 18:06:38][WoE/IV Calculation for f77] End   ...[Elapsed: 40.50s]
# [2018-07-05 18:06:38][WoE/IV Calculation for f100] Begin ...
# [2018-07-05 18:06:41][WoE/IV Calculation for f60] End   ...[Elapsed: 60.33s]
# [2018-07-05 18:06:41][WoE/IV Calculation for f101] Begin ...
# [2018-07-05 18:06:42][WoE/IV Calculation for f50] End   ...[Elapsed: 72.92s]
# [2018-07-05 18:06:42][WoE/IV Calculation for f102] Begin ...
# [2018-07-05 18:06:43][WoE/IV Calculation for f84] End   ...[Elapsed: 35.00s]
# [2018-07-05 18:06:43][WoE/IV Calculation for f103] Begin ...
# [2018-07-05 18:06:43][WoE/IV Calculation for f85] End   ...[Elapsed: 34.31s]
# [2018-07-05 18:06:43][WoE/IV Calculation for f104] Begin ...
# [2018-07-05 18:06:44][WoE/IV Calculation for f55] End   ...[Elapsed: 70.77s]
# [2018-07-05 18:06:44][WoE/IV Calculation for f105] Begin ...
# [2018-07-05 18:06:45][WoE/IV Calculation for f63] End   ...[Elapsed: 62.07s]
# [2018-07-05 18:06:45][WoE/IV Calculation for f106] Begin ...
# [2018-07-05 18:06:47][WoE/IV Calculation for f44] End   ...[Elapsed: 85.14s]
# [2018-07-05 18:06:47][WoE/IV Calculation for f107] Begin ...
# [2018-07-05 18:06:51][WoE/IV Calculation for f79] End   ...[Elapsed: 50.69s]
# [2018-07-05 18:06:51][WoE/IV Calculation for f108] Begin ...
# [2018-07-05 18:06:55][WoE/IV Calculation for f59] End   ...[Elapsed: 74.73s]
# [2018-07-05 18:06:55][WoE/IV Calculation for f109] Begin ...
# [2018-07-05 18:07:03][WoE/IV Calculation for f86] End   ...[Elapsed: 51.44s]
# [2018-07-05 18:07:03][WoE/IV Calculation for f110] Begin ...
# [2018-07-05 18:07:03][WoE/IV Calculation for f87] End   ...[Elapsed: 50.40s]
# [2018-07-05 18:07:03][WoE/IV Calculation for f111] Begin ...
# [2018-07-05 18:07:04][WoE/IV Calculation for f88] End   ...[Elapsed: 45.80s]
# [2018-07-05 18:07:04][WoE/IV Calculation for f112] Begin ...
# [2018-07-05 18:07:06][WoE/IV Calculation for f69] End   ...[Elapsed: 77.14s]
# [2018-07-05 18:07:07][WoE/IV Calculation for f113] Begin ...
# [2018-07-05 18:07:09][WoE/IV Calculation for f89] End   ...[Elapsed: 45.78s]
# [2018-07-05 18:07:09][WoE/IV Calculation for f114] Begin ...
# [2018-07-05 18:07:12][WoE/IV Calculation for f54] End   ...[Elapsed: 100.29s]
# [2018-07-05 18:07:12][WoE/IV Calculation for f115] Begin ...
# [2018-07-05 18:07:16][WoE/IV Calculation for f96] End   ...[Elapsed: 42.50s]
# [2018-07-05 18:07:16][WoE/IV Calculation for f116] Begin ...
# [2018-07-05 18:07:17][WoE/IV Calculation for f67] End   ...[Elapsed: 88.92s]
# [2018-07-05 18:07:17][WoE/IV Calculation for f117] Begin ...
# [2018-07-05 18:07:19][WoE/IV Calculation for f98] End   ...[Elapsed: 44.69s]
# [2018-07-05 18:07:19][WoE/IV Calculation for f118] Begin ...
# [2018-07-05 18:07:20][WoE/IV Calculation for f103] End   ...[Elapsed: 37.25s]
# [2018-07-05 18:07:20][WoE/IV Calculation for f119] Begin ...
# [2018-07-05 18:07:20][WoE/IV Calculation for f90] End   ...[Elapsed: 55.63s]
# [2018-07-05 18:07:20][WoE/IV Calculation for f120] Begin ...
# [2018-07-05 18:07:20][WoE/IV Calculation for f70] End   ...[Elapsed: 90.40s]
# [2018-07-05 18:07:20][WoE/IV Calculation for f121] Begin ...
# [2018-07-05 18:07:21][WoE/IV Calculation for f93] End   ...[Elapsed: 50.91s]
# [2018-07-05 18:07:21][WoE/IV Calculation for f122] Begin ...
# [2018-07-05 18:07:21][WoE/IV Calculation for f92] End   ...[Elapsed: 51.41s]
# [2018-07-05 18:07:21][WoE/IV Calculation for f123] Begin ...
# [2018-07-05 18:07:21][WoE/IV Calculation for f94] End   ...[Elapsed: 49.21s]
# [2018-07-05 18:07:21][WoE/IV Calculation for f104] End   ...[Elapsed: 38.54s]
# [2018-07-05 18:07:21][WoE/IV Calculation for f124] Begin ...
# [2018-07-05 18:07:21][WoE/IV Calculation for f125] Begin ...
# [2018-07-05 18:07:22][WoE/IV Calculation for f91] End   ...[Elapsed: 55.07s]
# [2018-07-05 18:07:22][WoE/IV Calculation for f126] Begin ...
# [2018-07-05 18:07:24][WoE/IV Calculation for f81] End   ...[Elapsed: 80.68s]
# [2018-07-05 18:07:24][WoE/IV Calculation for f127] Begin ...
# [2018-07-05 18:07:28][WoE/IV Calculation for f82] End   ...[Elapsed: 83.95s]
# [2018-07-05 18:07:28][WoE/IV Calculation for f128] Begin ...
# [2018-07-05 18:07:36][WoE/IV Calculation for f100] End   ...[Elapsed: 58.78s]
# [2018-07-05 18:07:36][WoE/IV Calculation for f129] Begin ...
# [2018-07-05 18:07:37][WoE/IV Calculation for f76] End   ...[Elapsed: 101.55s]
# [2018-07-05 18:07:37][WoE/IV Calculation for f130] Begin ...
# [2018-07-05 18:07:38][WoE/IV Calculation for f71] End   ...[Elapsed: 105.05s]
# [2018-07-05 18:07:38][WoE/IV Calculation for f131] Begin ...
# [2018-07-05 18:07:39][WoE/IV Calculation for f66] End   ...[Elapsed: 113.00s]
# [2018-07-05 18:07:39][WoE/IV Calculation for f132] Begin ...
# [2018-07-05 18:07:42][WoE/IV Calculation for f106] End   ...[Elapsed: 57.68s]
# [2018-07-05 18:07:42][WoE/IV Calculation for f133] Begin ...
# [2018-07-05 18:07:42][WoE/IV Calculation for f109] End   ...[Elapsed: 47.56s]
# [2018-07-05 18:07:42][WoE/IV Calculation for f134] Begin ...
# [2018-07-05 18:07:43][WoE/IV Calculation for f78] End   ...[Elapsed: 105.43s]
# [2018-07-05 18:07:43][WoE/IV Calculation for f135] Begin ...
# [2018-07-05 18:07:45][WoE/IV Calculation for f112] End   ...[Elapsed: 40.81s]
# [2018-07-05 18:07:45][WoE/IV Calculation for f136] Begin ...
# [2018-07-05 18:07:45][WoE/IV Calculation for f83] End   ...[Elapsed: 99.80s]
# [2018-07-05 18:07:45][WoE/IV Calculation for f137] Begin ...
# [2018-07-05 18:07:47][WoE/IV Calculation for f114] End   ...[Elapsed: 37.26s]
# [2018-07-05 18:07:47][WoE/IV Calculation for f138] Begin ...
# [2018-07-05 18:07:48][WoE/IV Calculation for f101] End   ...[Elapsed: 67.64s]
# [2018-07-05 18:07:48][WoE/IV Calculation for f139] Begin ...
# [2018-07-05 18:07:49][WoE/IV Calculation for f111] End   ...[Elapsed: 45.49s]
# [2018-07-05 18:07:49][WoE/IV Calculation for f140] Begin ...
# [2018-07-05 18:07:50][WoE/IV Calculation for f95] End   ...[Elapsed: 77.19s]
# [2018-07-05 18:07:50][WoE/IV Calculation for f141] Begin ...
# [2018-07-05 18:07:55][WoE/IV Calculation for f118] End   ...[Elapsed: 36.13s]
# [2018-07-05 18:07:55][WoE/IV Calculation for f142] Begin ...
# [2018-07-05 18:07:57][WoE/IV Calculation for f74] End   ...[Elapsed: 121.88s]
# [2018-07-05 18:07:57][WoE/IV Calculation for f143] Begin ...
# [2018-07-05 18:07:57][WoE/IV Calculation for f110] End   ...[Elapsed: 54.52s]
# [2018-07-05 18:07:57][WoE/IV Calculation for f144] Begin ...
# [2018-07-05 18:07:57][WoE/IV Calculation for f119] End   ...[Elapsed: 37.69s]
# [2018-07-05 18:07:57][WoE/IV Calculation for f145] Begin ...
# [2018-07-05 18:07:59][WoE/IV Calculation for f97] End   ...[Elapsed: 84.77s]
# [2018-07-05 18:07:59][WoE/IV Calculation for f146] Begin ...
# [2018-07-05 18:08:00][WoE/IV Calculation for f124] End   ...[Elapsed: 38.26s]
# [2018-07-05 18:08:00][WoE/IV Calculation for f147] Begin ...
# [2018-07-05 18:08:01][WoE/IV Calculation for f122] End   ...[Elapsed: 39.73s]
# [2018-07-05 18:08:01][WoE/IV Calculation for f148] Begin ...
# [2018-07-05 18:08:01][WoE/IV Calculation for f116] End   ...[Elapsed: 45.04s]
# [2018-07-05 18:08:01][WoE/IV Calculation for f149] Begin ...
# [2018-07-05 18:08:01][WoE/IV Calculation for f125] End   ...[Elapsed: 39.95s]
# [2018-07-05 18:08:01][WoE/IV Calculation for f150] Begin ...
# [2018-07-05 18:08:02][WoE/IV Calculation for f72] End   ...[Elapsed: 128.01s]
# [2018-07-05 18:08:02][WoE/IV Calculation for f151] Begin ...
# [2018-07-05 18:08:02][WoE/IV Calculation for f73] End   ...[Elapsed: 127.19s]
# [2018-07-05 18:08:02][WoE/IV Calculation for f152] Begin ...
# [2018-07-05 18:08:02][WoE/IV Calculation for f126] End   ...[Elapsed: 39.68s]
# [2018-07-05 18:08:02][WoE/IV Calculation for f153] Begin ...
# [2018-07-05 18:08:04][WoE/IV Calculation for f80] End   ...[Elapsed: 120.96s]
# [2018-07-05 18:08:04][WoE/IV Calculation for f154] Begin ...
# [2018-07-05 18:08:05][WoE/IV Calculation for f123] End   ...[Elapsed: 43.70s]
# [2018-07-05 18:08:05][WoE/IV Calculation for f155] Begin ...
# [2018-07-05 18:08:06][WoE/IV Calculation for f120] End   ...[Elapsed: 46.50s]
# [2018-07-05 18:08:06][WoE/IV Calculation for f156] Begin ...
# [2018-07-05 18:08:09][WoE/IV Calculation for f99] End   ...[Elapsed: 92.15s]
# [2018-07-05 18:08:09][WoE/IV Calculation for f157] Begin ...
# [2018-07-05 18:08:09][WoE/IV Calculation for f113] End   ...[Elapsed: 62.64s]
# [2018-07-05 18:08:09][WoE/IV Calculation for f158] Begin ...
# [2018-07-05 18:08:11][WoE/IV Calculation for f65] End   ...[Elapsed: 146.23s]
# [2018-07-05 18:08:11][WoE/IV Calculation for f159] Begin ...
# [2018-07-05 18:08:16][WoE/IV Calculation for f108] End   ...[Elapsed: 84.55s]
# [2018-07-05 18:08:16][WoE/IV Calculation for f160] Begin ...
# [2018-07-05 18:08:21][WoE/IV Calculation for f136] End   ...[Elapsed: 36.64s]
# [2018-07-05 18:08:21][WoE/IV Calculation for f161] Begin ...
# [2018-07-05 18:08:27][WoE/IV Calculation for f127] End   ...[Elapsed: 62.89s]
# [2018-07-05 18:08:27][WoE/IV Calculation for f162] Begin ...
# [2018-07-05 18:08:28][WoE/IV Calculation for f129] End   ...[Elapsed: 51.43s]
# [2018-07-05 18:08:28][WoE/IV Calculation for f163] Begin ...
# [2018-07-05 18:08:31][WoE/IV Calculation for f138] End   ...[Elapsed: 44.39s]
# [2018-07-05 18:08:31][WoE/IV Calculation for f164] Begin ...
# [2018-07-05 18:08:31][WoE/IV Calculation for f142] End   ...[Elapsed: 36.46s]
# [2018-07-05 18:08:31][WoE/IV Calculation for f165] Begin ...
# [2018-07-05 18:08:32][WoE/IV Calculation for f134] End   ...[Elapsed: 50.01s]
# [2018-07-05 18:08:32][WoE/IV Calculation for f166] Begin ...
# [2018-07-05 18:08:33][WoE/IV Calculation for f141] End   ...[Elapsed: 43.31s]
# [2018-07-05 18:08:33][WoE/IV Calculation for f167] Begin ...
# [2018-07-05 18:08:37][WoE/IV Calculation for f107] End   ...[Elapsed: 109.89s]
# [2018-07-05 18:08:37][WoE/IV Calculation for f168] Begin ...
# [2018-07-05 18:08:37][WoE/IV Calculation for f145] End   ...[Elapsed: 39.45s]
# [2018-07-05 18:08:37][WoE/IV Calculation for f169] Begin ...
# [2018-07-05 18:08:37][WoE/IV Calculation for f148] End   ...[Elapsed: 36.83s]
# [2018-07-05 18:08:37][WoE/IV Calculation for f170] Begin ...
# [2018-07-05 18:08:38][WoE/IV Calculation for f133] End   ...[Elapsed: 55.57s]
# [2018-07-05 18:08:38][WoE/IV Calculation for f171] Begin ...
# [2018-07-05 18:08:38][WoE/IV Calculation for f102] End   ...[Elapsed: 116.45s]
# [2018-07-05 18:08:38][WoE/IV Calculation for f172] Begin ...
# [2018-07-05 18:08:40][WoE/IV Calculation for f147] End   ...[Elapsed: 39.96s]
# [2018-07-05 18:08:40][WoE/IV Calculation for f173] Begin ...
# [2018-07-05 18:08:41][WoE/IV Calculation for f140] End   ...[Elapsed: 51.76s]
# [2018-07-05 18:08:41][WoE/IV Calculation for f174] Begin ...
# [2018-07-05 18:08:41][WoE/IV Calculation for f150] End   ...[Elapsed: 39.97s]
# [2018-07-05 18:08:41][WoE/IV Calculation for f175] Begin ...
# [2018-07-05 18:08:42][WoE/IV Calculation for f139] End   ...[Elapsed: 53.75s]
# [2018-07-05 18:08:42][WoE/IV Calculation for f176] Begin ...
# [2018-07-05 18:08:46][WoE/IV Calculation for f153] End   ...[Elapsed: 43.94s]
# [2018-07-05 18:08:46][WoE/IV Calculation for f177] Begin ...
# [2018-07-05 18:08:46][WoE/IV Calculation for f144] End   ...[Elapsed: 49.19s]
# [2018-07-05 18:08:46][WoE/IV Calculation for f178] Begin ...
# [2018-07-05 18:08:50][WoE/IV Calculation for f117] End   ...[Elapsed: 92.91s]
# [2018-07-05 18:08:50][WoE/IV Calculation for f179] Begin ...
# [2018-07-05 18:08:52][WoE/IV Calculation for f158] End   ...[Elapsed: 43.19s]
# [2018-07-05 18:08:52][WoE/IV Calculation for f180] Begin ...
# [2018-07-05 18:08:53][WoE/IV Calculation for f157] End   ...[Elapsed: 44.38s]
# [2018-07-05 18:08:53][WoE/IV Calculation for f181] Begin ...
# [2018-07-05 18:08:53][WoE/IV Calculation for f155] End   ...[Elapsed: 48.07s]
# [2018-07-05 18:08:53][WoE/IV Calculation for f182] Begin ...
# [2018-07-05 18:08:55][WoE/IV Calculation for f161] End   ...[Elapsed: 33.26s]
# [2018-07-05 18:08:55][WoE/IV Calculation for f183] Begin ...
# [2018-07-05 18:08:55][WoE/IV Calculation for f149] End   ...[Elapsed: 53.95s]
# [2018-07-05 18:08:55][WoE/IV Calculation for f184] Begin ...
# [2018-07-05 18:08:56][WoE/IV Calculation for f115] End   ...[Elapsed: 103.81s]
# [2018-07-05 18:08:56][WoE/IV Calculation for f185] Begin ...
# [2018-07-05 18:08:56][WoE/IV Calculation for f135] End   ...[Elapsed: 73.49s]
# [2018-07-05 18:08:57][WoE/IV Calculation for f186] Begin ...
# [2018-07-05 18:08:58][WoE/IV Calculation for f130] End   ...[Elapsed: 80.75s]
# [2018-07-05 18:08:58][WoE/IV Calculation for f187] Begin ...
# [2018-07-05 18:08:59][WoE/IV Calculation for f105] End   ...[Elapsed: 134.76s]
# [2018-07-05 18:08:59][WoE/IV Calculation for f188] Begin ...
# [2018-07-05 18:08:59][WoE/IV Calculation for f128] End   ...[Elapsed: 91.48s]
# [2018-07-05 18:08:59][WoE/IV Calculation for f189] Begin ...
# [2018-07-05 18:09:03][WoE/IV Calculation for f156] End   ...[Elapsed: 56.84s]
# [2018-07-05 18:09:03][WoE/IV Calculation for f190] Begin ...
# [2018-07-05 18:09:04][WoE/IV Calculation for f159] End   ...[Elapsed: 52.52s]
# [2018-07-05 18:09:04][WoE/IV Calculation for f191] Begin ...
# [2018-07-05 18:09:04][WoE/IV Calculation for f165] End   ...[Elapsed: 32.72s]
# [2018-07-05 18:09:04][WoE/IV Calculation for f192] Begin ...
# [2018-07-05 18:09:06][WoE/IV Calculation for f164] End   ...[Elapsed: 34.68s]
# [2018-07-05 18:09:06][WoE/IV Calculation for f193] Begin ...
# [2018-07-05 18:09:09][WoE/IV Calculation for f121] End   ...[Elapsed: 108.45s]
# [2018-07-05 18:09:09][WoE/IV Calculation for f194] Begin ...
# [2018-07-05 18:09:10][WoE/IV Calculation for f137] End   ...[Elapsed: 84.67s]
# [2018-07-05 18:09:10][WoE/IV Calculation for f195] Begin ...
# [2018-07-05 18:09:11][WoE/IV Calculation for f163] End   ...[Elapsed: 42.95s]
# [2018-07-05 18:09:11][WoE/IV Calculation for f196] Begin ...
# [2018-07-05 18:09:16][WoE/IV Calculation for f167] End   ...[Elapsed: 42.22s]
# [2018-07-05 18:09:16][WoE/IV Calculation for f197] Begin ...
# [2018-07-05 18:09:16][WoE/IV Calculation for f162] End   ...[Elapsed: 48.65s]
# [2018-07-05 18:09:16][WoE/IV Calculation for f198] Begin ...
# [2018-07-05 18:09:18][WoE/IV Calculation for f160] End   ...[Elapsed: 61.91s]
# [2018-07-05 18:09:18][WoE/IV Calculation for f199] Begin ...
# [2018-07-05 18:09:18][WoE/IV Calculation for f131] End   ...[Elapsed: 100.25s]
# [2018-07-05 18:09:18][WoE/IV Calculation for f200] Begin ...
# [2018-07-05 18:09:19][WoE/IV Calculation for f143] End   ...[Elapsed: 82.20s]
# [2018-07-05 18:09:19][WoE/IV Calculation for f201] Begin ...
# [2018-07-05 18:09:20][WoE/IV Calculation for f170] End   ...[Elapsed: 42.31s]
# [2018-07-05 18:09:20][WoE/IV Calculation for f202] Begin ...
# [2018-07-05 18:09:20][WoE/IV Calculation for f169] End   ...[Elapsed: 43.40s]
# [2018-07-05 18:09:20][WoE/IV Calculation for f203] Begin ...
# [2018-07-05 18:09:21][WoE/IV Calculation for f154] End   ...[Elapsed: 76.70s]
# [2018-07-05 18:09:21][WoE/IV Calculation for f204] Begin ...
# [2018-07-05 18:09:21][WoE/IV Calculation for f166] End   ...[Elapsed: 48.72s]
# [2018-07-05 18:09:21][WoE/IV Calculation for f205] Begin ...
# [2018-07-05 18:09:21][WoE/IV Calculation for f152] End   ...[Elapsed: 79.42s]
# [2018-07-05 18:09:21][WoE/IV Calculation for f206] Begin ...
# [2018-07-05 18:09:25][WoE/IV Calculation for f173] End   ...[Elapsed: 45.20s]
# [2018-07-05 18:09:25][WoE/IV Calculation for f207] Begin ...
# [2018-07-05 18:09:26][WoE/IV Calculation for f132] End   ...[Elapsed: 107.49s]
# [2018-07-05 18:09:26][WoE/IV Calculation for f208] Begin ...
# [2018-07-05 18:09:26][WoE/IV Calculation for f175] End   ...[Elapsed: 44.74s]
# [2018-07-05 18:09:26][WoE/IV Calculation for f209] Begin ...
# [2018-07-05 18:09:28][WoE/IV Calculation for f146] End   ...[Elapsed: 89.78s]
# [2018-07-05 18:09:28][WoE/IV Calculation for f210] Begin ...
# [2018-07-05 18:09:31][WoE/IV Calculation for f151] End   ...[Elapsed: 88.94s]
# [2018-07-05 18:09:31][WoE/IV Calculation for f211] Begin ...
# [2018-07-05 18:09:31][WoE/IV Calculation for f171] End   ...[Elapsed: 52.84s]
# [2018-07-05 18:09:31][WoE/IV Calculation for f212] Begin ...
# [2018-07-05 18:09:34][WoE/IV Calculation for f174] End   ...[Elapsed: 53.03s]
# [2018-07-05 18:09:34][WoE/IV Calculation for f213] Begin ...
# [2018-07-05 18:09:34][WoE/IV Calculation for f168] End   ...[Elapsed: 57.73s]
# [2018-07-05 18:09:34][WoE/IV Calculation for f214] Begin ...
# [2018-07-05 18:09:36][WoE/IV Calculation for f176] End   ...[Elapsed: 54.08s]
# [2018-07-05 18:09:36][WoE/IV Calculation for f215] Begin ...
# [2018-07-05 18:09:38][WoE/IV Calculation for f182] End   ...[Elapsed: 44.63s]
# [2018-07-05 18:09:38][WoE/IV Calculation for f216] Begin ...
# [2018-07-05 18:09:38][WoE/IV Calculation for f181] End   ...[Elapsed: 44.89s]
# [2018-07-05 18:09:38][WoE/IV Calculation for f217] Begin ...
# [2018-07-05 18:09:38][WoE/IV Calculation for f177] End   ...[Elapsed: 52.03s]
# [2018-07-05 18:09:38][WoE/IV Calculation for f218] Begin ...
# [2018-07-05 18:09:39][WoE/IV Calculation for f180] End   ...[Elapsed: 46.74s]
# [2018-07-05 18:09:39][WoE/IV Calculation for f219] Begin ...
# [2018-07-05 18:09:41][WoE/IV Calculation for f183] End   ...[Elapsed: 46.61s]
# [2018-07-05 18:09:41][WoE/IV Calculation for f220] Begin ...
# [2018-07-05 18:09:43][WoE/IV Calculation for f179] End   ...[Elapsed: 52.35s]
# [2018-07-05 18:09:43][WoE/IV Calculation for f221] Begin ...
# [2018-07-05 18:09:43][WoE/IV Calculation for f178] End   ...[Elapsed: 57.11s]
# [2018-07-05 18:09:43][WoE/IV Calculation for f222] Begin ...
# [2018-07-05 18:09:45][WoE/IV Calculation for f172] End   ...[Elapsed: 66.97s]
# [2018-07-05 18:09:45][WoE/IV Calculation for f223] Begin ...
# [2018-07-05 18:09:49][WoE/IV Calculation for f192] End   ...[Elapsed: 45.11s]
# [2018-07-05 18:09:49][WoE/IV Calculation for f224] Begin ...
# [2018-07-05 18:09:51][WoE/IV Calculation for f187] End   ...[Elapsed: 53.53s]
# [2018-07-05 18:09:51][WoE/IV Calculation for f225] Begin ...
# [2018-07-05 18:09:52][WoE/IV Calculation for f191] End   ...[Elapsed: 48.25s]
# [2018-07-05 18:09:52][WoE/IV Calculation for f226] Begin ...
# [2018-07-05 18:09:56][WoE/IV Calculation for f190] End   ...[Elapsed: 52.25s]
# [2018-07-05 18:09:56][WoE/IV Calculation for f227] Begin ...
# [2018-07-05 18:09:57][WoE/IV Calculation for f184] End   ...[Elapsed: 61.54s]
# [2018-07-05 18:09:57][WoE/IV Calculation for f228] Begin ...
# [2018-07-05 18:09:57][WoE/IV Calculation for f193] End   ...[Elapsed: 51.39s]
# [2018-07-05 18:09:57][WoE/IV Calculation for f229] Begin ...
# [2018-07-05 18:09:59][WoE/IV Calculation for f196] End   ...[Elapsed: 48.60s]
# [2018-07-05 18:09:59][WoE/IV Calculation for f230] Begin ...
# [2018-07-05 18:10:01][WoE/IV Calculation for f197] End   ...[Elapsed: 45.71s]
# [2018-07-05 18:10:01][WoE/IV Calculation for f231] Begin ...
# [2018-07-05 18:10:03][WoE/IV Calculation for f205] End   ...[Elapsed: 41.68s]
# [2018-07-05 18:10:03][WoE/IV Calculation for f232] Begin ...
# [2018-07-05 18:10:03][WoE/IV Calculation for f188] End   ...[Elapsed: 63.84s]
# [2018-07-05 18:10:03][WoE/IV Calculation for f233] Begin ...
# [2018-07-05 18:10:03][WoE/IV Calculation for f199] End   ...[Elapsed: 45.52s]
# [2018-07-05 18:10:03][WoE/IV Calculation for f234] Begin ...
# [2018-07-05 18:10:04][WoE/IV Calculation for f202] End   ...[Elapsed: 43.80s]
# [2018-07-05 18:10:04][WoE/IV Calculation for f235] Begin ...
# [2018-07-05 18:10:04][WoE/IV Calculation for f189] End   ...[Elapsed: 64.52s]
# [2018-07-05 18:10:04][WoE/IV Calculation for f236] Begin ...
# [2018-07-05 18:10:05][WoE/IV Calculation for f186] End   ...[Elapsed: 68.44s]
# [2018-07-05 18:10:05][WoE/IV Calculation for f237] Begin ...
# [2018-07-05 18:10:05][WoE/IV Calculation for f198] End   ...[Elapsed: 49.00s]
# [2018-07-05 18:10:05][WoE/IV Calculation for f238] Begin ...
# [2018-07-05 18:10:05][WoE/IV Calculation for f207] End   ...[Elapsed: 40.42s]
# [2018-07-05 18:10:05][WoE/IV Calculation for f239] Begin ...
# [2018-07-05 18:10:05][WoE/IV Calculation for f209] End   ...[Elapsed: 39.22s]
# [2018-07-05 18:10:05][WoE/IV Calculation for f240] Begin ...
# [2018-07-05 18:10:07][WoE/IV Calculation for f194] End   ...[Elapsed: 57.99s]
# [2018-07-05 18:10:07][WoE/IV Calculation for f241] Begin ...
# [2018-07-05 18:10:07][WoE/IV Calculation for f195] End   ...[Elapsed: 57.30s]
# [2018-07-05 18:10:07][WoE/IV Calculation for f242] Begin ...
# [2018-07-05 18:10:09][WoE/IV Calculation for f203] End   ...[Elapsed: 48.39s]
# [2018-07-05 18:10:09][WoE/IV Calculation for f243] Begin ...
# [2018-07-05 18:10:12][WoE/IV Calculation for f213] End   ...[Elapsed: 38.13s]
# [2018-07-05 18:10:12][WoE/IV Calculation for f244] Begin ...
# [2018-07-05 18:10:12][WoE/IV Calculation for f212] End   ...[Elapsed: 41.51s]
# [2018-07-05 18:10:12][WoE/IV Calculation for f245] Begin ...
# [2018-07-05 18:10:12][WoE/IV Calculation for f185] End   ...[Elapsed: 76.32s]
# [2018-07-05 18:10:12][WoE/IV Calculation for f246] Begin ...
# [2018-07-05 18:10:13][WoE/IV Calculation for f217] End   ...[Elapsed: 35.37s]
# [2018-07-05 18:10:13][WoE/IV Calculation for f247] Begin ...
# [2018-07-05 18:10:14][WoE/IV Calculation for f215] End   ...[Elapsed: 37.42s]
# [2018-07-05 18:10:14][WoE/IV Calculation for f248] Begin ...
# [2018-07-05 18:10:14][WoE/IV Calculation for f214] End   ...[Elapsed: 39.60s]
# [2018-07-05 18:10:14][WoE/IV Calculation for f249] Begin ...
# [2018-07-05 18:10:15][WoE/IV Calculation for f204] End   ...[Elapsed: 54.43s]
# [2018-07-05 18:10:15][WoE/IV Calculation for f250] Begin ...
# [2018-07-05 18:10:15][WoE/IV Calculation for f216] End   ...[Elapsed: 37.64s]
# [2018-07-05 18:10:15][WoE/IV Calculation for f251] Begin ...
# [2018-07-05 18:10:18][WoE/IV Calculation for f211] End   ...[Elapsed: 47.74s]
# [2018-07-05 18:10:18][WoE/IV Calculation for f252] Begin ...
# [2018-07-05 18:10:19][WoE/IV Calculation for f200] End   ...[Elapsed: 60.30s]
# [2018-07-05 18:10:19][WoE/IV Calculation for f253] Begin ...
# [2018-07-05 18:10:20][WoE/IV Calculation for f218] End   ...[Elapsed: 42.06s]
# [2018-07-05 18:10:20][WoE/IV Calculation for f254] Begin ...
# [2018-07-05 18:10:22][WoE/IV Calculation for f201] End   ...[Elapsed: 62.67s]
# [2018-07-05 18:10:22][WoE/IV Calculation for f255] Begin ...
# [2018-07-05 18:10:26][WoE/IV Calculation for f226] End   ...[Elapsed: 33.73s]
# [2018-07-05 18:10:26][WoE/IV Calculation for f256] Begin ...
# [2018-07-05 18:10:27][WoE/IV Calculation for f225] End   ...[Elapsed: 35.66s]
# [2018-07-05 18:10:27][WoE/IV Calculation for f257] Begin ...
# [2018-07-05 18:10:29][WoE/IV Calculation for f224] End   ...[Elapsed: 39.83s]
# [2018-07-05 18:10:29][WoE/IV Calculation for f258] Begin ...
# [2018-07-05 18:10:29][WoE/IV Calculation for f229] End   ...[Elapsed: 32.44s]
# [2018-07-05 18:10:29][WoE/IV Calculation for f259] Begin ...
# [2018-07-05 18:10:33][WoE/IV Calculation for f228] End   ...[Elapsed: 36.22s]
# [2018-07-05 18:10:33][WoE/IV Calculation for f260] Begin ...
# [2018-07-05 18:10:33][WoE/IV Calculation for f222] End   ...[Elapsed: 49.54s]
# [2018-07-05 18:10:33][WoE/IV Calculation for f261] Begin ...
# [2018-07-05 18:10:33][WoE/IV Calculation for f219] End   ...[Elapsed: 53.91s]
# [2018-07-05 18:10:33][WoE/IV Calculation for f262] Begin ...
# [2018-07-05 18:10:36][WoE/IV Calculation for f231] End   ...[Elapsed: 34.92s]
# [2018-07-05 18:10:36][WoE/IV Calculation for f263] Begin ...
# [2018-07-05 18:10:37][WoE/IV Calculation for f223] End   ...[Elapsed: 52.42s]
# [2018-07-05 18:10:37][WoE/IV Calculation for f264] Begin ...
# [2018-07-05 18:10:38][WoE/IV Calculation for f240] End   ...[Elapsed: 32.26s]
# [2018-07-05 18:10:38][WoE/IV Calculation for f265] Begin ...
# [2018-07-05 18:10:38][WoE/IV Calculation for f239] End   ...[Elapsed: 32.60s]
# [2018-07-05 18:10:38][WoE/IV Calculation for f266] Begin ...
# [2018-07-05 18:10:39][WoE/IV Calculation for f232] End   ...[Elapsed: 36.15s]
# [2018-07-05 18:10:39][WoE/IV Calculation for f267] Begin ...
# [2018-07-05 18:10:39][WoE/IV Calculation for f221] End   ...[Elapsed: 56.64s]
# [2018-07-05 18:10:39][WoE/IV Calculation for f268] Begin ...
# [2018-07-05 18:10:40][WoE/IV Calculation for f235] End   ...[Elapsed: 35.98s]
# [2018-07-05 18:10:40][WoE/IV Calculation for f269] Begin ...
# [2018-07-05 18:10:40][WoE/IV Calculation for f230] End   ...[Elapsed: 40.79s]
# [2018-07-05 18:10:40][WoE/IV Calculation for f270] Begin ...
# [2018-07-05 18:10:42][WoE/IV Calculation for f227] End   ...[Elapsed: 46.02s]
# [2018-07-05 18:10:42][WoE/IV Calculation for f271] Begin ...
# [2018-07-05 18:10:42][WoE/IV Calculation for f233] End   ...[Elapsed: 38.71s]
# [2018-07-05 18:10:42][WoE/IV Calculation for f272] Begin ...
# [2018-07-05 18:10:42][WoE/IV Calculation for f234] End   ...[Elapsed: 38.45s]
# [2018-07-05 18:10:42][WoE/IV Calculation for f273] Begin ...
# [2018-07-05 18:10:43][WoE/IV Calculation for f210] End   ...[Elapsed: 74.33s]
# [2018-07-05 18:10:43][WoE/IV Calculation for f274] Begin ...
# [2018-07-05 18:10:43][WoE/IV Calculation for f220] End   ...[Elapsed: 61.66s]
# [2018-07-05 18:10:43][WoE/IV Calculation for f275] Begin ...
# [2018-07-05 18:10:44][WoE/IV Calculation for f243] End   ...[Elapsed: 34.85s]
# [2018-07-05 18:10:44][WoE/IV Calculation for f276] Begin ...
# [2018-07-05 18:10:44][WoE/IV Calculation for f238] End   ...[Elapsed: 39.22s]
# [2018-07-05 18:10:44][WoE/IV Calculation for f277] Begin ...
# [2018-07-05 18:10:46][WoE/IV Calculation for f206] End   ...[Elapsed: 84.33s]
# [2018-07-05 18:10:46][WoE/IV Calculation for f278] Begin ...
# [2018-07-05 18:10:47][WoE/IV Calculation for f247] End   ...[Elapsed: 34.14s]
# [2018-07-05 18:10:47][WoE/IV Calculation for f279] Begin ...
# [2018-07-05 18:10:49][WoE/IV Calculation for f251] End   ...[Elapsed: 34.10s]
# [2018-07-05 18:10:49][WoE/IV Calculation for f280] Begin ...
# [2018-07-05 18:10:50][WoE/IV Calculation for f241] End   ...[Elapsed: 42.88s]
# [2018-07-05 18:10:50][WoE/IV Calculation for f281] Begin ...
# [2018-07-05 18:10:51][WoE/IV Calculation for f236] End   ...[Elapsed: 46.73s]
# [2018-07-05 18:10:51][WoE/IV Calculation for f282] Begin ...
# [2018-07-05 18:10:52][WoE/IV Calculation for f245] End   ...[Elapsed: 39.51s]
# [2018-07-05 18:10:52][WoE/IV Calculation for f283] Begin ...
# [2018-07-05 18:10:54][WoE/IV Calculation for f242] End   ...[Elapsed: 46.17s]
# [2018-07-05 18:10:54][WoE/IV Calculation for f249] End   ...[Elapsed: 39.71s]
# [2018-07-05 18:10:54][WoE/IV Calculation for f285] Begin ...
# [2018-07-05 18:10:54][WoE/IV Calculation for f284] Begin ...
# [2018-07-05 18:10:55][WoE/IV Calculation for f237] End   ...[Elapsed: 50.33s]
# [2018-07-05 18:10:55][WoE/IV Calculation for f286] Begin ...
# [2018-07-05 18:10:55][WoE/IV Calculation for f246] End   ...[Elapsed: 43.07s]
# [2018-07-05 18:10:55][WoE/IV Calculation for f287] Begin ...
# [2018-07-05 18:10:56][WoE/IV Calculation for f248] End   ...[Elapsed: 42.12s]
# [2018-07-05 18:10:56][WoE/IV Calculation for f288] Begin ...
# [2018-07-05 18:10:57][WoE/IV Calculation for f244] End   ...[Elapsed: 45.54s]
# [2018-07-05 18:10:57][WoE/IV Calculation for f289] Begin ...
# [2018-07-05 18:10:59][WoE/IV Calculation for f250] End   ...[Elapsed: 43.75s]
# [2018-07-05 18:10:59][WoE/IV Calculation for f290] Begin ...
# [2018-07-05 18:11:04][WoE/IV Calculation for f254] End   ...[Elapsed: 43.56s]
# [2018-07-05 18:11:04][WoE/IV Calculation for f291] Begin ...
# [2018-07-05 18:11:04][WoE/IV Calculation for f253] End   ...[Elapsed: 45.09s]
# [2018-07-05 18:11:04][WoE/IV Calculation for f292] Begin ...
# [2018-07-05 18:11:04][WoE/IV Calculation for f252] End   ...[Elapsed: 45.78s]
# [2018-07-05 18:11:04][WoE/IV Calculation for f293] Begin ...
# [2018-07-05 18:11:05][WoE/IV Calculation for f259] End   ...[Elapsed: 35.16s]
# [2018-07-05 18:11:05][WoE/IV Calculation for f294] Begin ...
# [2018-07-05 18:11:07][WoE/IV Calculation for f261] End   ...[Elapsed: 33.94s]
# [2018-07-05 18:11:07][WoE/IV Calculation for f295] Begin ...
# [2018-07-05 18:11:09][WoE/IV Calculation for f256] End   ...[Elapsed: 43.17s]
# [2018-07-05 18:11:09][WoE/IV Calculation for f296] Begin ...
# [2018-07-05 18:11:10][WoE/IV Calculation for f257] End   ...[Elapsed: 43.13s]
# [2018-07-05 18:11:10][WoE/IV Calculation for f297] Begin ...
# [2018-07-05 18:11:14][WoE/IV Calculation for f263] End   ...[Elapsed: 37.39s]
# [2018-07-05 18:11:14][WoE/IV Calculation for f260] End   ...[Elapsed: 40.84s]
# [2018-07-05 18:11:16][WoE/IV Calculation for f255] End   ...[Elapsed: 54.14s]
# [2018-07-05 18:11:16][WoE/IV Calculation for f265] End   ...[Elapsed: 38.59s]
# [2018-07-05 18:11:16][WoE/IV Calculation for f266] End   ...[Elapsed: 38.52s]
# [2018-07-05 18:11:22][WoE/IV Calculation for f258] End   ...[Elapsed: 53.01s]
# [2018-07-05 18:11:23][WoE/IV Calculation for f271] End   ...[Elapsed: 41.24s]
# [2018-07-05 18:11:24][WoE/IV Calculation for f208] End   ...[Elapsed: 117.52s]
# [2018-07-05 18:11:24][WoE/IV Calculation for f279] End   ...[Elapsed: 36.75s]
# [2018-07-05 18:11:24][WoE/IV Calculation for f270] End   ...[Elapsed: 44.04s]
# [2018-07-05 18:11:25][WoE/IV Calculation for f262] End   ...[Elapsed: 52.48s]
# [2018-07-05 18:11:25][WoE/IV Calculation for f280] End   ...[Elapsed: 36.03s]
# [2018-07-05 18:11:26][WoE/IV Calculation for f272] End   ...[Elapsed: 43.98s]
# [2018-07-05 18:11:26][WoE/IV Calculation for f276] End   ...[Elapsed: 42.17s]
# [2018-07-05 18:11:27][WoE/IV Calculation for f268] End   ...[Elapsed: 47.54s]
# [2018-07-05 18:11:27][WoE/IV Calculation for f269] End   ...[Elapsed: 47.70s]
# [2018-07-05 18:11:29][WoE/IV Calculation for f264] End   ...[Elapsed: 51.80s]
# [2018-07-05 18:11:32][WoE/IV Calculation for f275] End   ...[Elapsed: 48.69s]
# [2018-07-05 18:11:32][WoE/IV Calculation for f283] End   ...[Elapsed: 40.22s]
# [2018-07-05 18:11:33][WoE/IV Calculation for f267] End   ...[Elapsed: 53.87s]
# [2018-07-05 18:11:34][WoE/IV Calculation for f288] End   ...[Elapsed: 37.84s]
# [2018-07-05 18:11:34][WoE/IV Calculation for f285] End   ...[Elapsed: 40.54s]
# [2018-07-05 18:11:34][WoE/IV Calculation for f273] End   ...[Elapsed: 52.31s]
# [2018-07-05 18:11:35][WoE/IV Calculation for f282] End   ...[Elapsed: 44.00s]
# [2018-07-05 18:11:36][WoE/IV Calculation for f281] End   ...[Elapsed: 46.70s]
# [2018-07-05 18:11:36][WoE/IV Calculation for f284] End   ...[Elapsed: 42.79s]
# [2018-07-05 18:11:37][WoE/IV Calculation for f289] End   ...[Elapsed: 39.24s]
# [2018-07-05 18:11:38][WoE/IV Calculation for f277] End   ...[Elapsed: 53.40s]
# [2018-07-05 18:11:38][WoE/IV Calculation for f294] End   ...[Elapsed: 33.46s]
# [2018-07-05 18:11:38][WoE/IV Calculation for f291] End   ...[Elapsed: 34.72s]
# [2018-07-05 18:11:39][WoE/IV Calculation for f274] End   ...[Elapsed: 55.74s]
# [2018-07-05 18:11:40][WoE/IV Calculation for f295] End   ...[Elapsed: 32.85s]
# [2018-07-05 18:11:43][WoE/IV Calculation for f287] End   ...[Elapsed: 47.76s]
# [2018-07-05 18:11:45][WoE/IV Calculation for f286] End   ...[Elapsed: 49.23s]
# [2018-07-05 18:11:46][WoE/IV Calculation for f296] End   ...[Elapsed: 37.27s]
# [2018-07-05 18:11:47][WoE/IV Calculation for f297] End   ...[Elapsed: 36.58s]
# [2018-07-05 18:11:52][WoE/IV Calculation for f290] End   ...[Elapsed: 52.97s]
# [2018-07-05 18:11:53][WoE/IV Calculation for f292] End   ...[Elapsed: 49.09s]
# [2018-07-05 18:11:57][WoE/IV Calculation for f278] End   ...[Elapsed: 71.28s]
# [2018-07-05 18:11:59][WoE/IV Calculation for f293] End   ...[Elapsed: 55.37s]

# %%
woe_table['f5']
# Out:
#    Variable Value     All    Good   Bad     Share  Bad Rate  \
# 0        f5   100     200      64   136  0.000201  0.680000
# 1        f5   109       8       8     0  0.000008  0.000000
# 2        f5   200      86      86     0  0.000086  0.000000
# 3        f5   201      60      60     0  0.000060  0.000000
# 4        f5   203       4       4     0  0.000004  0.000000
# 5        f5   205       7       7     0  0.000007  0.000000
# 6        f5   206       4       4     0  0.000004  0.000000
# 7        f5   307       6       6     0  0.000006  0.000000
# 8        f5   401       9       9     0  0.000009  0.000000
# 9        f5   402       4       4     0  0.000004  0.000000
# 10       f5   403      29      29     0  0.000029  0.000000
# 11       f5   404       7       7     0  0.000007  0.000000
# 12       f5   405       4       4     0  0.000004  0.000000
# 13       f5   500       3       3     0  0.000003  0.000000
# 14       f5   501     502     469    33  0.000505  0.065737
# 15       f5   502     767     742    25  0.000771  0.032595
# 16       f5   503     101     101     0  0.000102  0.000000
# 17       f5   504       2       2     0  0.000002  0.000000
# 18       f5   505      37      37     0  0.000037  0.000000
# 19       f5   508       9       9     0  0.000009  0.000000
# 20       f5   509      52      52     0  0.000052  0.000000
# 21       f5   511       2       2     0  0.000002  0.000000
# 22       f5   527       6       6     0  0.000006  0.000000
# 23       f5   531       2       2     0  0.000002  0.000000
# 24       f5   600       4       4     0  0.000004  0.000000
# 25       f5   601     102     102     0  0.000103  0.000000
# 26       f5   602      12      12     0  0.000012  0.000000
# 27       f5   603      17      17     0  0.000017  0.000000
# 28       f5   604      48      48     0  0.000048  0.000000
# 29       f5   605       4       4     0  0.000004  0.000000
# ..      ...   ...     ...     ...   ...       ...       ...
# 35       f5   611     597     597     0  0.000600  0.000000
# 36       f5   701      18      18     0  0.000018  0.000000
# 37       f5   702      19      19     0  0.000019  0.000000
# 38       f5   703       8       8     0  0.000008  0.000000
# 39       f5   801       2       2     0  0.000002  0.000000
# 40       f5   802      27      27     0  0.000027  0.000000
# 41       f5   803      39      39     0  0.000039  0.000000
# 42       f5   804       2       2     0  0.000002  0.000000
# 43       f5   900     156      29   127  0.000157  0.814103
# 44       f5   901     187     115    72  0.000188  0.385027
# 45       f5   902      22      22     0  0.000022  0.000000
# 46       f5   903       1       1     0  0.000001  0.000000
# 47       f5   905      29      29     0  0.000029  0.000000
# 48       f5   906      58      58     0  0.000058  0.000000
# 49       f5   909     181     181     0  0.000182  0.000000
# 50       f5  1000   10341   10336     5  0.010396  0.000484
# 51       f5  1001   42213   42193    20  0.042437  0.000474
# 52       f5  1002      27      20     7  0.000027  0.259259
# 53       f5  1003   13150   13090    60  0.013220  0.004563
# 54       f5  1004     354     350     4  0.000356  0.011299
# 55       f5  1005     520     515     5  0.000523  0.009615
# 56       f5  1006   25549   25234   315  0.025684  0.012329
# 57       f5  1007   12879   12694   185  0.012947  0.014364
# 58       f5  1008  684445  679671  4774  0.688070  0.006975
# 59       f5  1500     166     124    42  0.000167  0.253012
# 60       f5  1501     113      76    37  0.000114  0.327434
# 61       f5  1502    1177     867   310  0.001183  0.263381
# 62       f5  1503     229     187    42  0.000230  0.183406
# 63       f5  1504     112     103     9  0.000113  0.080357
# 64       f5  NULL  199825  193911  5914  0.200883  0.029596
#
#     Distribution Good  Distribution Bad       WoE        IV
# 0            0.000065          0.011219 -5.148961  0.057432
# 1            0.000008          0.000000  0.000000  0.000000
# 2            0.000088          0.000000  0.000000  0.000000
# 3            0.000061          0.000000  0.000000  0.000000
# 4            0.000004          0.000000  0.000000  0.000000
# 5            0.000007          0.000000  0.000000  0.000000
# 6            0.000004          0.000000  0.000000  0.000000
# 7            0.000006          0.000000  0.000000  0.000000
# 8            0.000009          0.000000  0.000000  0.000000
# 9            0.000004          0.000000  0.000000  0.000000
# 10           0.000030          0.000000  0.000000  0.000000
# 11           0.000007          0.000000  0.000000  0.000000
# 12           0.000004          0.000000  0.000000  0.000000
# 13           0.000003          0.000000  0.000000  0.000000
# 14           0.000477          0.002722 -1.741094  0.003909
# 15           0.000755          0.002062 -1.004716  0.001313
# 16           0.000103          0.000000  0.000000  0.000000
# 17           0.000002          0.000000  0.000000  0.000000
# 18           0.000038          0.000000  0.000000  0.000000
# 19           0.000009          0.000000  0.000000  0.000000
# 20           0.000053          0.000000  0.000000  0.000000
# 21           0.000002          0.000000  0.000000  0.000000
# 22           0.000006          0.000000  0.000000  0.000000
# 23           0.000002          0.000000  0.000000  0.000000
# 24           0.000004          0.000000  0.000000  0.000000
# 25           0.000104          0.000000  0.000000  0.000000
# 26           0.000012          0.000000  0.000000  0.000000
# 27           0.000017          0.000000  0.000000  0.000000
# 28           0.000049          0.000000  0.000000  0.000000
# 29           0.000004          0.000000  0.000000  0.000000
# ..                ...               ...       ...       ...
# 35           0.000608          0.000000  0.000000  0.000000
# 36           0.000018          0.000000  0.000000  0.000000
# 37           0.000019          0.000000  0.000000  0.000000
# 38           0.000008          0.000000  0.000000  0.000000
# 39           0.000002          0.000000  0.000000  0.000000
# 40           0.000027          0.000000  0.000000  0.000000
# 41           0.000040          0.000000  0.000000  0.000000
# 42           0.000002          0.000000  0.000000  0.000000
# 43           0.000030          0.010477 -5.872081  0.061347
# 44           0.000117          0.005940 -3.926923  0.022865
# 45           0.000022          0.000000  0.000000  0.000000
# 46           0.000001          0.000000  0.000000  0.000000
# 47           0.000030          0.000000  0.000000  0.000000
# 48           0.000059          0.000000  0.000000  0.000000
# 49           0.000184          0.000000  0.000000  0.000000
# 50           0.010519          0.000412  3.238761  0.032732
# 51           0.042940          0.001650  3.259088  0.134567
# 52           0.000020          0.000577 -3.345367  0.001864
# 53           0.013322          0.004950  0.990070  0.008289
# 54           0.000356          0.000330  0.076449  0.000002
# 55           0.000524          0.000412  0.239540  0.000027
# 56           0.025681          0.025986 -0.011814  0.000004
# 57           0.012919          0.015262 -0.166660  0.000390
# 58           0.691700          0.393829  0.563235  0.167771
# 59           0.000126          0.003465 -3.312577  0.011059
# 60           0.000077          0.003052 -3.675374  0.010934
# 61           0.000882          0.025573 -3.366723  0.083128
# 62           0.000190          0.003465 -2.901750  0.009502
# 63           0.000105          0.000742 -1.957685  0.001248
# 64           0.197343          0.487873 -0.905112  0.262963
#
# [65 rows x 11 columns]

# %%
iv_df = pd.DataFrame()
iv_df['IV'] = pd.DataFrame.from_dict(iv_list,orient='index')[0]
iv_df['Type'] = pd.DataFrame.from_dict(type_list,orient='index')[0]
iv_df.sort_values('IV',ascending=False).head(20)
# Out:
#             IV      Type
# f31   2.446697  category
# f30   2.408117  category
# f29   2.164999  category
# f28   2.158825  category
# f259  1.971594     value
# f52   1.864613  category
# f261  1.855937     value
# f260  1.847208     value
# f264  1.815180     value
# f271  1.810987     value
# f262  1.748509     value
# f270  1.745205     value
# f263  1.569084     value
# f265  1.459363     value
# f204  1.429896     value
# f266  1.384927     value
# f24   1.276831     value
# f25   1.256769     value
# f274  1.214360  category
# f276  1.200266  category

# %%
iv_df.loc['f7']
# Out:
# IV       1.08217
# Type    category
# Name: f7, dtype: object

# %%
iv_df.loc['NaN_LIST']
# Out:
# IV      0.753456
# Type    category
# Name: NaN_LIST, dtype: object

# %%
important_feature = list(iv_df[ (iv_df.IV > 0.3) & (iv_df.IV < 0.8)].index)

# %%
filter_feature = important_feature 
#list(set(important_feature) -set(atecml.data.NOT_IMP_FEATURE))
print(len(filter_feature))
rename_dict ={}
new_filter_feature_list = []
for item in filter_feature:
    old_feature_name = item
    new_feature_name = 'n_' + item
    new_filter_feature_list.append(new_feature_name)
    rename_dict[old_feature_name] = new_feature_name
# Out:
# 177

# %%
iv_df[iv_df.index.isin(filter_feature) & (iv_df.Type == 'category']
# Out:
#             IV      Type
# f209  0.576994     value
# f198  0.652486  category
# f64   0.307117     value
# f186  0.499122  category
# f183  0.786403  category
# f21   0.630004     value
# f115  0.301456     value
# f267  0.520601  category
# f291  0.488016     value
# f153  0.333371     value
# f254  0.499649  category
# f87   0.395637  category
# f196  0.561158  category
# f216  0.476881     value
# f90   0.496106  category
# f14   0.451264  category
# f190  0.602945  category
# f111  0.380421     value
# f119  0.421919     value
# f70   0.490231     value
# f120  0.303781     value
# f103  0.406259     value
# f278  0.435588     value
# f68   0.528134     value
# f72   0.316533     value
# f88   0.433358  category
# f215  0.639120     value
# f195  0.513858  category
# f91   0.452521  category
# f148  0.360185     value
# ...        ...       ...
# f269  0.661852  category
# f82   0.348409     value
# f297  0.378338     value
# f122  0.331570     value
# f200  0.514998  category
# f49   0.444154     value
# f296  0.373914     value
# f114  0.300935     value
# f97   0.750854     value
# f292  0.536973     value
# f199  0.499081  category
# f293  0.370806     value
# f201  0.564669  category
# f71   0.417443     value
# f178  0.577551  category
# f175  0.492993  category
# f280  0.726895     value
# f137  0.306192     value
# f121  0.301975     value
# f147  0.370345     value
# f85   0.341712     value
# f81   0.319442     value
# f289  0.463907     value
# f93   0.461470  category
# f54   0.699109     value
# f180  0.495083  category
# f197  0.641548  category
# f170  0.582884  category
# f282  0.431343     value
# f202  0.660086  category
#
# [177 rows x 2 columns]

# %%
joblib.dump(new_filter_feature_list,'./woe_feature.dat')
# Out:
# ['./woe_feature.dat']

# %% [markdown]
# # 使用WOE/IV结果对原有训练集特征纬度提升

# %%
test_df = atecml.data.load_train()
test_df['f5'] =test_df['f5']//100

a = train_df['f5'].unique()
test_df['f5'][~test_df['f5'].isin(a)] =np.nan

def mt_conv_test(feature):
    return atecml.data.woe_convert(df=test_df,feature=feature,woe_table=woe_table,type_list=type_list,category_num=num_cat)

new_feature_tt =[]
with ProcessPoolExecutor(max_workers=60) as pool:
    for pool_result in pool.map(mt_conv_test,predictors):
        new_feature_tt.append(pool_result)

nan_result = mt_conv_test('NaN_LIST')   
new_feature_tt.append(nan_result)
        
_t_new_tt_df = pd.concat(new_feature_tt,axis=1)

_t_new_tt_df = _t_new_tt_df[filter_feature]

mean = _t_new_tt_df.mean(axis=1)
variance = _t_new_tt_df.var(axis=1)
skew = _t_new_tt_df.skew(axis=1)
_t_new_tt_df['mean'] = mean
#_t_new_tt_df['variance'] = variance
#_t_new_tt_df['skew'] = skew
_t_new_tt_df.rename(columns=rename_dict,inplace=True)
ext_tt_df = pd.concat([test_df,_t_new_tt_df],axis=1)
ext_tt_df.to_pickle('./01_train.dat')

# %%
test_df = atecml.data.load_test()
test_df['f5'] =test_df['f5']//100

a = train_df['f5'].unique()
test_df['f5'][~test_df['f5'].isin(a)] =np.nan

def mt_conv_test(feature):
    return atecml.data.woe_convert(df=test_df,feature=feature,woe_table=woe_table,type_list=type_list,category_num=num_cat)

new_feature_tt =[]
with ProcessPoolExecutor(max_workers=60) as pool:
    for pool_result in pool.map(mt_conv_test,predictors):
        new_feature_tt.append(pool_result)

nan_result = mt_conv_test('NaN_LIST')   
new_feature_tt.append(nan_result)        
        
_t_new_tt_df = pd.concat(new_feature_tt,axis=1)

_t_new_tt_df = _t_new_tt_df[filter_feature]

mean = _t_new_tt_df.mean(axis=1)
variance = _t_new_tt_df.var(axis=1)
skew = _t_new_tt_df.skew(axis=1)
_t_new_tt_df['mean'] = mean
#_t_new_tt_df['variance'] = variance
#_t_new_tt_df['skew'] = skew
_t_new_tt_df.rename(columns=rename_dict,inplace=True)
ext_tt_df = pd.concat([test_df,_t_new_tt_df],axis=1)
ext_tt_df.to_pickle('./01_test.dat')

# %%
test_df = atecml.data.load_train()
test_df['f5'] =test_df['f5']//100

a = train_df['f5'].unique()
test_df['f5'][~test_df['f5'].isin(a)] =np.nan

def mt_conv_test(feature):
    return atecml.data.woe_convert(df=test_df,feature=feature,woe_table=woe_table,type_list=type_list,category_num=num_cat)

new_feature_tt =[]
with ProcessPoolExecutor(max_workers=60) as pool:
    for pool_result in pool.map(mt_conv_test,predictors):
        new_feature_tt.append(pool_result)
        
_t_new_tt_df = pd.concat(new_feature_tt,axis=1)

_t_new_tt_df = _t_new_tt_df[filter_feature]

mean = _t_new_tt_df.mean(axis=1)
variance = _t_new_tt_df.var(axis=1)
skew = _t_new_tt_df.skew(axis=1)
_t_new_tt_df['mean'] = mean
#_t_new_tt_df['variance'] = variance
#_t_new_tt_df['skew'] = skew
_t_new_tt_df.rename(columns=rename_dict,inplace=True)
ext_tt_df = pd.concat([test_df,_t_new_tt_df],axis=1)

# %%
foo = ext_tt_df[['mean','label']]

# %%
foo.groupby('label').describe()

# %%
foo[foo.label==1]['mean'].hist(bins=50)

# %%
foo[foo.label==0]['mean'].hist(bins=50)

# %%
foo[foo.label==-1]['mean'].hist(bins=50)
