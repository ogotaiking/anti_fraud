# %% [markdown]
# # Step.2 KGB(known Good/Bad)训练，用于检测拒绝集(训练集中的unknown标签)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import os

import numpy as np
import pandas as pd
import atecml.data
from tqdm import tqdm

class BasicModel(object):
    """Parent class of basic models"""
    def train(self, x_train, y_train, x_val, y_val):
        """return a trained model and eval metric o validation data"""
        pass
    
    def predict(self, model, x_test):
        """return the predicted result"""
        pass
    
    def get_oof(self, x_train, y_train, x_test, n_folds = 5):
        """K-fold stacking"""
        num_train, num_test = x_train.shape[0], x_test.shape[0]
        oof_train = np.zeros((num_train,)) 
        oof_test = np.zeros((num_test,))
        oof_test_all_fold = np.zeros((num_test, n_folds))
        aucs = []
        model_list = []
        
        for i in range(0,n_folds):
            
            val_index = DateFold[5] #始终用最后20%验证            
            train_index = list(all_list - DateFold[i])
                            
            print('{0} fold, train {1}, val {2}'.format(i, len(train_index), len(val_index)))
            x_tra, y_tra = x_train[train_index], y_train[train_index]
            x_val, y_val = x_train[val_index], y_train[val_index]
            
            #Over_sample
            #X_resampled, y_resampled = SMOTE().fit_sample(x_tra,y_tra)
            #model, auc = self.train(X_resampled, y_resampled, x_val, y_val)
            model, auc = self.train(x_tra, y_tra, x_val, y_val)
            aucs.append(auc)
            model_list.append(model)
            oof_train[val_index] = self.predict(model, x_val)
            oof_test_all_fold[:, i] = self.predict(model, x_test)
        oof_test = np.mean(oof_test_all_fold, axis=1)
        print('all aucs {0}, average {1}'.format(aucs, np.mean(aucs)))
        return oof_train, oof_test,model_list

import lightgbm as lgb
class LGBClassifier(BasicModel):
    '''
    ' 调参范围
    'num_leaves':range(35,65,5)
    'learning_rate':[0.01,0.05,0.1,0.3,0.5,0.7]
    'min_child_weight':range(1,6,2)
    'max_depth':range(3,10,2),
    'subsample':[i/10.0 for i in range(6,10)],正常直接设置为1
    'colsample_bytree':[i/10.0 for i in range(6,10)]，正常直接设置为1
    'reg_alpha','reg_lambda':[1e-5, 1e-2, 0.1, 1, 2,2.5,3]
    '''
    def __init__(self,boost_type,boost_round=1000,early_stop=100,pos_weight=1):
        self.num_boost_round = boost_round
        self.early_stopping_rounds = early_stop
        self.params = {
            'task': 'train',
            'boosting_type': boost_type,
            'colsample_bytree': 0.7,
            'learning_rate': 0.05,
            'max_bin': 255,
            'max_depth': -1,
            'metric': {'auc'},
            'min_child_samples': 600,
            'min_child_weight': 0.05,
            'min_split_gain': 0,
            'nthread': 40,
            'num_leaves': 80,
            'objective': 'binary',
            'reg_alpha': 0.1,
            'reg_lambda': 0.1,
            #'is_unbalance':'true',
            'scale_pos_weight': pos_weight,
            'subsample': 0.85,
            'subsample_for_bin': 200000,
            'subsample_freq': 1,
            'use_missing': 'true',
            'verbose' : -1,
            }
        print(self.params)
        
    def train(self, x_train, y_train, x_val, y_val):
        print('train with lgb model')
        lgbtrain = lgb.Dataset(x_train, y_train)
        lgbval = lgb.Dataset(x_val, y_val)
        model = lgb.train(self.params, 
                          lgbtrain,
                          valid_sets=lgbval, 
                          verbose_eval = 50,
                          num_boost_round = self.num_boost_round,
                          early_stopping_rounds = self.early_stopping_rounds)
        return model, model.best_score['valid_0']['auc']
    
    def predict(self, model, x_test):
        print('test with lgb model')
        return model.predict(x_test, num_iteration=model.best_iteration)

def stack_layer1_result(X_train,rf_model_list,gbdt_model_list,dart_model_list):
    with atecml.data.timer('Classification: Building Layer-1 Stack'):
        rf_input_list = []
        for idx in tqdm(range(len(rf_model_list))):
            model = rf_model_list[idx]
            _temp_df = model.predict(X_train,num_iteration=model.best_iteration)
            rf_input_list.append(pd.DataFrame(_temp_df))
        rf_oof_predict= np.array(pd.concat(rf_input_list,ignore_index=True,axis=1).mean(axis=1))    
    
        gbdt_input_list = []
        for idx in tqdm(range(len(gbdt_model_list))):
            model = gbdt_model_list[idx]
            _temp_df = model.predict(X_train,num_iteration=model.best_iteration)
            gbdt_input_list.append(pd.DataFrame(_temp_df))
        gbdt_oof_predict= np.array(pd.concat(gbdt_input_list,ignore_index=True,axis=1).mean(axis=1))
        
        
        dart_input_list = []
        for idx in tqdm(range(len(dart_model_list))):
            model = dart_model_list[idx]
            _temp_df = model.predict(X_train,num_iteration=model.best_iteration)
            dart_input_list.append(pd.DataFrame(_temp_df))
        dart_oof_predict= np.array(pd.concat(dart_input_list,ignore_index=True,axis=1).mean(axis=1))
    
    input_predict = [rf_oof_predict, gbdt_oof_predict, dart_oof_predict] 
    stacked_predict = np.concatenate([f.reshape(-1, 1) for f in input_predict], axis=1)
    
    return stacked_predict
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#训练集为第一步build的纬度提升矩阵，并过滤掉unknown标签
data = pd.read_pickle('./01_train.dat')
train_df = data[data['label']!=-1].reset_index(drop=True)

#最终预测的测试集为unknown标签
val_df = data[data['label']==-1].reset_index(drop=True)

predictors = [x for x in data.columns if x not in atecml.data.NOT_FEATURE_COLUMNS]
target = 'label'
DateFold={}

DateFold[0] = set(atecml.data.filter_date(train_df,start_date='2017-09-05',end_date='2017-09-12').index)
DateFold[1] = set(atecml.data.filter_date(train_df,start_date='2017-09-13',end_date='2017-09-20').index)
DateFold[2] = set(atecml.data.filter_date(train_df,start_date='2017-09-21',end_date='2017-09-28').index)
DateFold[3] = set(atecml.data.filter_date(train_df,start_date='2017-09-29',end_date='2017-10-06').index)
DateFold[4] = set(atecml.data.filter_date(train_df,start_date='2017-10-07',end_date='2017-10-14').index)
DateFold[5] = list(atecml.data.filter_date(train_df,start_date='2017-10-15',end_date='2017-11-24').index)

all_list = set(train_df.index) - set(DateFold[5])
len(all_list),len(DateFold[5])
# Out:
# (631141, 358865)

# %%
x_train = np.array(train_df[predictors])
y_train = np.array(train_df[target])
x_test = np.array(val_df[predictors])
print(x_train.shape, y_train.shape, x_test.shape)
# Out:
# (990006, 480) (990006,) (4725, 480)

# %%
num_pos = np.sum(train_df[target])  
num_neg = x_train.shape[0]- num_pos
scale_pos_weight =  num_neg/num_pos
print(num_pos,num_neg,scale_pos_weight)
# Out:
# 12122 977884 80.67018643788154

# %%
num_boost_round = 2000
num_early_stop = 100

# %%
# get output of first layer models and construct as input for the second layer          
rf_classifier = LGBClassifier(boost_type='rf',boost_round=num_boost_round,early_stop=num_early_stop,pos_weight= scale_pos_weight)
rf_oof_train, rf_oof_test,rf_model_list = rf_classifier.get_oof(x_train, y_train, x_test)
print(rf_oof_train.shape, rf_oof_test.shape)
# Out:
# {'min_child_samples': 600, 'colsample_bytree': 0.7, 'min_split_gain': 0, 'num_leaves': 80, 'nthread': 40, 'learning_rate': 0.05, 'subsample': 0.85, 'reg_alpha': 0.1, 'max_depth': -1, 'scale_pos_weight': 80.67018643788154, 'subsample_for_bin': 200000, 'max_bin': 255, 'task': 'train', 'verbose': -1, 'subsample_freq': 1, 'use_missing': 'true', 'metric': {'auc'}, 'min_child_weight': 0.05, 'reg_lambda': 0.1, 'objective': 'binary', 'boosting_type': 'rf'}
# 0 fold, train 498238, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.971312
# [100]	valid_0's auc: 0.971481
# Early stopping, best iteration is:
# [10]	valid_0's auc: 0.97354
# test with lgb model
# test with lgb model
# 1 fold, train 506877, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.970862
# [100]	valid_0's auc: 0.970676
# Early stopping, best iteration is:
# [12]	valid_0's auc: 0.972794
# test with lgb model
# test with lgb model
# 2 fold, train 506495, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.971156
# [100]	valid_0's auc: 0.971068
# Early stopping, best iteration is:
# [10]	valid_0's auc: 0.972381
# test with lgb model
# test with lgb model
# 3 fold, train 515851, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.969243
# [100]	valid_0's auc: 0.969222
# Early stopping, best iteration is:
# [13]	valid_0's auc: 0.969849
# test with lgb model
# test with lgb model
# 4 fold, train 497103, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.970259
# [100]	valid_0's auc: 0.969991
# [150]	valid_0's auc: 0.969755
# Early stopping, best iteration is:
# [52]	valid_0's auc: 0.970442
# test with lgb model
# test with lgb model
# all aucs [0.9735401978957983, 0.9727935143167116, 0.9723812817965433, 0.9698489846019138, 0.9704417915856131], average 0.971801154039316
# (990006,) (4725,)

# %%
gbdt_classifier = LGBClassifier(boost_type='gbdt',boost_round=num_boost_round,early_stop=num_early_stop,pos_weight= scale_pos_weight)
gbdt_oof_train, gbdt_oof_test,gbdt_model_list = gbdt_classifier.get_oof(x_train, y_train, x_test)
print(gbdt_oof_train.shape, gbdt_oof_test.shape)  

dart_classifier = LGBClassifier(boost_type='dart',boost_round=num_boost_round,early_stop=num_early_stop,pos_weight= scale_pos_weight)
dart_oof_train, dart_oof_test,dart_model_list = dart_classifier.get_oof(x_train, y_train, x_test)
print(dart_oof_train.shape, dart_oof_test.shape)
# Out:
# {'min_child_samples': 600, 'colsample_bytree': 0.7, 'min_split_gain': 0, 'num_leaves': 80, 'nthread': 40, 'learning_rate': 0.05, 'subsample': 0.85, 'reg_alpha': 0.1, 'max_depth': -1, 'scale_pos_weight': 80.67018643788154, 'subsample_for_bin': 200000, 'max_bin': 255, 'task': 'train', 'verbose': -1, 'subsample_freq': 1, 'use_missing': 'true', 'metric': {'auc'}, 'min_child_weight': 0.05, 'reg_lambda': 0.1, 'objective': 'binary', 'boosting_type': 'gbdt'}
# 0 fold, train 498238, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.977831
# [100]	valid_0's auc: 0.981571
# [150]	valid_0's auc: 0.983183
# [200]	valid_0's auc: 0.983421
# [250]	valid_0's auc: 0.983626
# [300]	valid_0's auc: 0.9837
# [350]	valid_0's auc: 0.983711
# [400]	valid_0's auc: 0.983759
# Early stopping, best iteration is:
# [312]	valid_0's auc: 0.983932
# test with lgb model
# test with lgb model
# 1 fold, train 506877, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.977804
# [100]	valid_0's auc: 0.981167
# [150]	valid_0's auc: 0.982924
# [200]	valid_0's auc: 0.983297
# [250]	valid_0's auc: 0.98322
# [300]	valid_0's auc: 0.983059
# Early stopping, best iteration is:
# [217]	valid_0's auc: 0.98348
# test with lgb model
# test with lgb model
# 2 fold, train 506495, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.979019
# [100]	valid_0's auc: 0.980868
# [150]	valid_0's auc: 0.981845
# [200]	valid_0's auc: 0.982114
# [250]	valid_0's auc: 0.981966
# [300]	valid_0's auc: 0.982428
# [350]	valid_0's auc: 0.982561
# [400]	valid_0's auc: 0.982161
# Early stopping, best iteration is:
# [337]	valid_0's auc: 0.982635
# test with lgb model
# test with lgb model
# 3 fold, train 515851, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.972636
# [100]	valid_0's auc: 0.978907
# [150]	valid_0's auc: 0.980948
# [200]	valid_0's auc: 0.9819
# [250]	valid_0's auc: 0.982138
# [300]	valid_0's auc: 0.982258
# [350]	valid_0's auc: 0.982229
# [400]	valid_0's auc: 0.982397
# [450]	valid_0's auc: 0.982362
# [500]	valid_0's auc: 0.982673
# [550]	valid_0's auc: 0.982499
# [600]	valid_0's auc: 0.982741
# [650]	valid_0's auc: 0.982876
# [700]	valid_0's auc: 0.982846
# [750]	valid_0's auc: 0.982718
# Early stopping, best iteration is:
# [674]	valid_0's auc: 0.982947
# test with lgb model
# test with lgb model
# 4 fold, train 497103, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.977632
# [100]	valid_0's auc: 0.981318
# [150]	valid_0's auc: 0.982887
# [200]	valid_0's auc: 0.982621
# [250]	valid_0's auc: 0.982382
# Early stopping, best iteration is:
# [171]	valid_0's auc: 0.982928
# test with lgb model
# test with lgb model
# all aucs [0.9839322508261203, 0.9834795548959302, 0.9826346742643584, 0.9829465211845196, 0.9829281681335247], average 0.9831842338608908
# (990006,) (4725,)
# {'min_child_samples': 600, 'colsample_bytree': 0.7, 'min_split_gain': 0, 'num_leaves': 80, 'nthread': 40, 'learning_rate': 0.05, 'subsample': 0.85, 'reg_alpha': 0.1, 'max_depth': -1, 'scale_pos_weight': 80.67018643788154, 'subsample_for_bin': 200000, 'max_bin': 255, 'task': 'train', 'verbose': -1, 'subsample_freq': 1, 'use_missing': 'true', 'metric': {'auc'}, 'min_child_weight': 0.05, 'reg_lambda': 0.1, 'objective': 'binary', 'boosting_type': 'dart'}
# 0 fold, train 498238, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.975776
# [100]	valid_0's auc: 0.976972
# [150]	valid_0's auc: 0.978039
# [200]	valid_0's auc: 0.979028
# [250]	valid_0's auc: 0.979829
# [300]	valid_0's auc: 0.980895
# [350]	valid_0's auc: 0.981183
# [400]	valid_0's auc: 0.982078
# [450]	valid_0's auc: 0.983104
# [500]	valid_0's auc: 0.983407
# [550]	valid_0's auc: 0.983348
# [600]	valid_0's auc: 0.983514
# [650]	valid_0's auc: 0.984114
# [700]	valid_0's auc: 0.984585
# [750]	valid_0's auc: 0.984549
# [800]	valid_0's auc: 0.984689
# [850]	valid_0's auc: 0.98471
# [900]	valid_0's auc: 0.984957
# [950]	valid_0's auc: 0.984999
# [1000]	valid_0's auc: 0.98502
# [1050]	valid_0's auc: 0.984937
# Early stopping, best iteration is:
# [962]	valid_0's auc: 0.985098
# test with lgb model
# test with lgb model
# 1 fold, train 506877, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.976221
# [100]	valid_0's auc: 0.977615
# [150]	valid_0's auc: 0.978034
# [200]	valid_0's auc: 0.978933
# [250]	valid_0's auc: 0.979923
# [300]	valid_0's auc: 0.98048
# [350]	valid_0's auc: 0.980931
# [400]	valid_0's auc: 0.981766
# [450]	valid_0's auc: 0.982313
# [500]	valid_0's auc: 0.982824
# [550]	valid_0's auc: 0.983241
# [600]	valid_0's auc: 0.983437
# [650]	valid_0's auc: 0.983646
# [700]	valid_0's auc: 0.983716
# Early stopping, best iteration is:
# [638]	valid_0's auc: 0.983932
# test with lgb model
# test with lgb model
# 2 fold, train 506495, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.977302
# [100]	valid_0's auc: 0.978046
# [150]	valid_0's auc: 0.978087
# [200]	valid_0's auc: 0.978691
# [250]	valid_0's auc: 0.97976
# [300]	valid_0's auc: 0.980276
# [350]	valid_0's auc: 0.980427
# [400]	valid_0's auc: 0.981419
# [450]	valid_0's auc: 0.982099
# [500]	valid_0's auc: 0.982715
# [550]	valid_0's auc: 0.982927
# [600]	valid_0's auc: 0.982941
# [650]	valid_0's auc: 0.983448
# [700]	valid_0's auc: 0.983375
# [750]	valid_0's auc: 0.98376
# [800]	valid_0's auc: 0.984152
# [850]	valid_0's auc: 0.984339
# [900]	valid_0's auc: 0.984329
# Early stopping, best iteration is:
# [822]	valid_0's auc: 0.984539
# test with lgb model
# test with lgb model
# 3 fold, train 515851, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.969301
# [100]	valid_0's auc: 0.975702
# [150]	valid_0's auc: 0.978057
# [200]	valid_0's auc: 0.979106
# [250]	valid_0's auc: 0.979799
# [300]	valid_0's auc: 0.981079
# [350]	valid_0's auc: 0.981582
# [400]	valid_0's auc: 0.981938
# [450]	valid_0's auc: 0.982808
# [500]	valid_0's auc: 0.983474
# [550]	valid_0's auc: 0.98415
# [600]	valid_0's auc: 0.983988
# [650]	valid_0's auc: 0.984223
# [700]	valid_0's auc: 0.984345
# [750]	valid_0's auc: 0.984644
# [800]	valid_0's auc: 0.984493
# [850]	valid_0's auc: 0.985055
# [900]	valid_0's auc: 0.984963
# [950]	valid_0's auc: 0.985012
# Early stopping, best iteration is:
# [883]	valid_0's auc: 0.985217
# test with lgb model
# test with lgb model
# 4 fold, train 497103, val 358865
# train with lgb model
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's auc: 0.975413
# [100]	valid_0's auc: 0.97735
# [150]	valid_0's auc: 0.977755
# [200]	valid_0's auc: 0.978824
# [250]	valid_0's auc: 0.979532
# [300]	valid_0's auc: 0.980633
# [350]	valid_0's auc: 0.981003
# [400]	valid_0's auc: 0.982282
# [450]	valid_0's auc: 0.982783
# [500]	valid_0's auc: 0.983506
# [550]	valid_0's auc: 0.984108
# [600]	valid_0's auc: 0.984053
# [650]	valid_0's auc: 0.983805
# Early stopping, best iteration is:
# [588]	valid_0's auc: 0.984259
# test with lgb model
# test with lgb model
# all aucs [0.9850980460788805, 0.9839318299979742, 0.9845393418505598, 0.9852166466644878, 0.9842588255255827], average 0.984608938023497
# (990006,) (4725,)

# %%
stacked_train = stack_layer1_result(x_train,rf_model_list,gbdt_model_list,dart_model_list)
stacked_test = stack_layer1_result(x_test,rf_model_list,gbdt_model_list,dart_model_list)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# [2018-07-03 14:55:03][Classification: Building Layer-1 Stack] Begin ...
# 100%|██████████| 5/5 [00:34<00:00,  6.90s/it]
# 100%|██████████| 5/5 [00:46<00:00,  9.44s/it]
# 100%|██████████| 5/5 [01:00<00:00, 12.04s/it]
#  80%|████████  | 4/5 [00:00<00:00, 34.29it/s]
# [2018-07-03 14:57:25][Classification: Building Layer-1 Stack] End   ...[Elapsed: 142.25s]
# [2018-07-03 14:57:25][Classification: Building Layer-1 Stack] Begin ...
# 100%|██████████| 5/5 [00:00<00:00, 30.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 23.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.35it/s]
# [2018-07-03 14:57:26][Classification: Building Layer-1 Stack] End   ...[Elapsed: 0.68s]

# %%
# use XGBOOST  as the model of the second layer
import xgboost as xgb
from xgboost.sklearn import XGBClassifier

model = XGBClassifier(
 learning_rate =0.05,
 n_estimators=200,
 max_depth=3,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.9,
 objective= 'binary:logistic',
 scoring='roc_auc',
 scale_pos_weight= scale_pos_weight,
 nthread=40,
 seed=27)


# split for validation
n = int(stacked_train.shape[0] * 0.8)
x_tra, y_tra = stacked_train[:n], y_train[:n]
x_val, y_val = stacked_train[n:], y_train[n:]
model.fit(x_tra,y_tra)
y_pred = pd.DataFrame(model.predict_proba(x_val))[1]

_f1,_f2,_f3 = atecml.data.accuracy_validation(y_val,y_pred)
# Out:
# Ant-Score: 0.4749809305873379

# %%
# predict on test data
final_model = XGBClassifier(
 learning_rate =0.05,
 n_estimators=200,
 max_depth=3,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.9,
 objective= 'binary:logistic',
 scoring='roc_auc',
 scale_pos_weight= scale_pos_weight,
 nthread=40,
 seed=27)


final_model.fit(stacked_train, y_train)
test_prediction = final_model.predict_proba(stacked_test)

result=pd.DataFrame()
result['id'] = val_df['id']
result['score'] = pd.DataFrame(test_prediction)[1]
result.to_pickle('./reject_inf.dat')

# %%
result.hist(bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4b5300bd30>]],
#       dtype=object)

# %%
len(result[result.score > 0.1])
# Out:
# 3611

# %%
result[result.score > 0.1].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4afb6a7780>]],
#       dtype=object)

# %%
result
# Out:
#                                                      id     score
# 0     3c4b3baa09510eec473f45079c7c7977fc01fdfed93a8b...  0.014134
# 1     643b560780177054c375bd2ddd8a1ac6b99b728f016c75...  0.953457
# 2     addd09c73d0bfa3d98e252865c3343b534db2f0701e089...  0.332501
# 3     f8e66a38649c631bc205bd9f5cb953e214b17a3d9c80f2...  0.026390
# 4     61dacd672d0d12112ae4c5a9f0aa7d348c9566ba60bda3...  0.036702
# 5     bbd743c945e39779d7136f90dcd6e005b04d6660dd65ec...  0.978902
# 6     072a5f1007ec94ff4e6547783ec3dff4c72073dcfe5dfa...  0.026390
# 7     3842de26f717890858813543c6938c0fdb346b3e3fc715...  0.096056
# 8     1ac41ee380516d13d2692b74eb08e7b33135fe8b745ca8...  0.367708
# 9     1e06c933127058d1d88c63084522d4aa19dd0d55bc61ee...  0.876338
# 10    9f428d802b2396a7882cd966b963a7ad293a4768b28b11...  0.018271
# 11    f94cc8efb2969dabc45a764afd70a7c5b1b7ea3a8364da...  0.869350
# 12    0e4bce4900fcf752297fa6874a42be8b735d11115f482d...  0.012849
# 13    d81fd6ae3ce09d9e0582a0b6b45f2c6e17cdd5b37f67d7...  0.336318
# 14    c213f2fd36918732c806d78fd668c90a6f7ff6b1c59240...  0.987841
# 15    43e03113a91c755faf38fe554ec40b370dbbba5675a071...  0.519126
# 16    46b10987f3002c1a94bc6005fc016093df1751d0dfeaeb...  0.866242
# 17    e36dce1ffefb8e45d7ff2abee2d5dd2600f4633596c133...  0.547132
# 18    459ae52a82b7745d21cbfac6ffd8d0644b3c74413e46f2...  0.205632
# 19    fd81fe03c33e15b40b778ebb05488d198576aec53ead4f...  0.088874
# 20    94848d1711b6cc7cc2cbaec33204dfd5e79e03547d7dd4...  0.649237
# 21    38bb143a5286e1c081485a014cb54be1c32077a59eea2d...  0.049247
# 22    e80512c0d8ef68a2eb1a1b3821cbc2465b3f4865305659...  0.973883
# 23    8c3a9df539e25acd0246c53eb01ad2f427548d3c728a00...  0.071605
# 24    c5cce37fa236210d019e6bab20945f4007036f48cd49a8...  0.201146
# 25    05bc443c034177f0b5e2317ed604d32b471156e2884ece...  0.981105
# 26    98ab7122e4b7ea506253dede3fdbf3f3b4fbda20cb6f03...  0.978932
# 27    79594e7e347d2bad6063b9742630a05292851958ea20ef...  0.082555
# 28    4c2e5d9e83b23ccc9bdb7e039dbbb091e5458ee32f0ab0...  0.104574
# 29    c9168f5d81262120217fd7c49ee7f7bd1047ea438e001c...  0.027464
# ...                                                 ...       ...
# 4695  ffc5b7b9e3448e8fb5c927c5462c678253dd0ef095f393...  0.797715
# 4696  5709ae32f6ede39296cb77d7eb70d73c135c78e780d1ee...  0.009886
# 4697  654bd1f1b355f894dd0e98ae4c40963b6e11564e1ca628...  0.213045
# 4698  ee13d5169a91fd90eed73a4ef96cb3b1c26d01c23ba431...  0.053452
# 4699  fd634e83b383189ed2be5e58de34e2cc9be85b7bf7757c...  0.455737
# 4700  f887f9ef0f5889b1012ba29cfb9ba7dbf8f3366e627867...  0.052497
# 4701  a57d1da427e71e17630fac7353d9285da4427264ece8e1...  0.055479
# 4702  41430fa7606905fd1254a2bebffe7c305d764949b56598...  0.069198
# 4703  7ccafd0187b748fbfa9718cdd282290b0966ee7f244d75...  0.985540
# 4704  4f967126f088cd479074d0499c8b4a5790fb26b7de66b7...  0.704231
# 4705  d20309055dc0afff198e895b2bafb70c87a35ea62d8ad4...  0.718632
# 4706  9a3495c753828085b8ebb7a6bc0367a2716b3d2c47af2f...  0.007089
# 4707  9d4b4c31d2b1f3d98940776c9c1ad0b78cd5e9b4f67183...  0.115652
# 4708  54afc0f366b69003b1877d45a7d4d6d52b64b1c51633eb...  0.092309
# 4709  6066d95b5de44ce2a7b823dabd0a34d168925a8c5c916f...  0.042927
# 4710  04dc3cefe45e8f1ad658c3f8093075ae5ecb2480f8da7c...  0.088910
# 4711  966ae9d49ec1785a0ded839f6c3da5f250f6723ba2a5f3...  0.146728
# 4712  4ee942e62ecc3a9c0f194e8447ddfb93173a4dc4a9b5a6...  0.166463
# 4713  18175179c6fa4287fc7b64ee3789b33b4ac169a13435e3...  0.993286
# 4714  4eee213f0a159f9ad5a8f691f93cffd1402aa8ca5a6369...  0.106036
# 4715  1788fb688e6fb84aee56e54a0102d5ad4e847a5d57be36...  0.027639
# 4716  6a865fca1cc17481d1166b338a65a6954c8a958efcd5c0...  0.046808
# 4717  9dd0ddba31e2969f581e15f3f716b8ee693d2813113dbd...  0.868907
# 4718  a570c9fb361dc378cdec154a852b8a4e7768d503ffb7ed...  0.089931
# 4719  6d7cf1d342d2c3afc836859485d2b1c5b5cb1df227ce55...  0.313810
# 4720  1fbffa27df4ed7a9f31a8415659cd89e5a17fef32ffdef...  0.524008
# 4721  062430a22b735793a16bc968dcb413eef441e42ae738b6...  0.539663
# 4722  441473c9777afccd1fc3029c24ae5f7c65aa498be68f9b...  0.182786
# 4723  68da191e9a9fbd6713047c4bb8a2651beeaf6a0e9f77a5...  0.969097
# 4724  2f3775077d406c5034d66800261e341ea697364972be98...  0.998329
#
# [4725 rows x 2 columns]
