# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns


import numpy as np
import pandas as pd
import tensorflow as tf

import atecml.data

from contextlib import contextmanager
from tqdm import tqdm
from time import strftime,time
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler

plt.style.use('ggplot')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
@contextmanager
def timer(func_name: str):
    """Elapsed Time
    """
    start = time()
    print('[{}][{}] Begin ...'.format(strftime('%Y-%m-%d %H:%M:%S'), func_name))
    yield
    print('[{}][{}] End   ...[Elapsed: {:.2f}s]'.format(strftime('%Y-%m-%d %H:%M:%S'), func_name, time()-start))

# %%
train_df,test_df = atecml.data.load()

# %%
from sklearn.metrics import log_loss
from MLFeatureSelection import FeatureSelection as FS
import lightgbm as lgb

# %%
predictors = [x for x in train_df.columns if x not in atecml.data.NOT_FEATURE_COLUMNS]

# %%
with timer('PreProcessing: fillna'):
    for idx in tqdm(range(len(predictors))):
        item = predictors[idx]
        train_df[item].fillna(train_df[item].min(), inplace=True)
# Out:
#   3%|▎         | 8/297 [00:00<00:03, 74.54it/s]
# [2018-06-21 20:41:45][PreProcessing: fillna] Begin ...
# 100%|██████████| 297/297 [00:05<00:00, 57.89it/s]
# [2018-06-21 20:41:50][PreProcessing: fillna] End   ...[Elapsed: 5.13s]

# %%
from sklearn.metrics import roc_curve
from sklearn.model_selection import StratifiedKFold

def score(y_test,y_predict_proba):
    """
    基于ROC的模型性能测量，并根据蚂蚁金服评分标准输出分数
    """
    fpr, tpr, thresholds = roc_curve(y_test,y_predict_proba)
    #roc_auc = auc(fpr, tpr)
    score = 0.4 * tpr[np.where(fpr >= 0.001)[0][0]] + \
            0.3 * tpr[np.where(fpr >= 0.005)[0][0]] + \
            0.3 * tpr[np.where(fpr >= 0.01)[0][0]]
    return score

def validation(X, Y, features, clf, lossfunction):
    totaltest = []
    kf = StratifiedKFold(n_splits=5, random_state=10, shuffle=True)
    for train_index, test_index in kf.split(X, Y):
        X_train, X_test = X.ix[train_index,:][features], X.ix[test_index,:][features]
        y_train, y_test = Y[train_index], Y[test_index]
        clf.fit(X_train, y_train)
        totaltest.append(lossfunction(y_test, clf.predict(X_test)))
    return np.mean(totaltest)

# %%
import lightgbm as lgb

sf = FS.Select(Sequence = True, Random = False, Cross = False) #初始化选择器，选择你需要的流程
sf.ImportDF(train_df, label ='Fraud') #导入数据集以及目标标签
#sf.ImportCrossMethod(CrossMethod)
sf.ImportLossFunction(score, direction = 'descend') #导入评价函数以及优化方向
sf.InitialNonTrainableFeatures(atecml.data.NOT_FEATURE_COLUMNS) #初始化不能用的特征
sf.InitialFeatures(predictors) #初始化其实特征组合
sf.GenerateCol() #生成特征库 （具体该函数变量请参考根目录下的readme）
sf.SetSample(1, samplemode = 1) #初始化抽样比例和随机过程
sf.SetTimeLimit(240) #设置算法运行最长时间，以分钟为单位
sf.clf = lgb.LGBMClassifier(random_state=10, num_leaves =15, n_estimators=200, max_depth=5, learning_rate = 0.1, n_jobs=-1) #设定模型
sf.SetLogFile('record.log') #初始化日志文件
sf.run(validation) #输入检验函数并开始运行
# Out:
# Features Quantity Limit: inf
# Time Limit: 240 min(s)
# test performance of initial features combination
# Mean loss: 0.7909591235412201
# --------------------start greedy--------------------
# f1
# f2
# f3
# f4
# f5
# f6
# f7
# f8
# f9
# f10
# f11
# f12
# f13
# f14
# f15
# f16
# f17
# f18
# f19
# f20
# f21
# f22
# f23
# f24
# f25
# f26
# f27
# f28
# f29
# f30
# f31
# f32
# f33
# f34
# f35
# f36
# f37
# f38
# f39
# f40
# f41
# f42
# f43
# f44
# f45
# f46
# f47
# f48
# f49
# f50
# f51
# f52
# f53
# f54
# f55
# f56
# f57
# f58
# f59
# f60
# f61
# f62
# f63
# f64
# f65
# f66
# f67
# f68
# f69
# f70
# f71
# f72
# f73
# f74
# f75
# f76
# f77
# f78
# f79
# f80
# f81
# f82
# f83
# f84
# f85
# f86
# f87
# f88
# f89
# f90
# f91
# f92
# f93
# f94
# f95
# f96
# f97
# f98
# f99
# f100
# f101
# f102
# f103
# f104
# f105
# f106
# f107
# f108
# f109
# f110
# f111
# f112
# f113
# f114
# f115
# f116
# f117
# f118
# f119
# f120
# f121
# f122
# f123
# f124
# f125
# f126
# f127
# f128
# f129
# f130
# f131
# f132
# f133
# f134
# f135
# f136
# f137
# f138
# f139
# f140
# f141
# f142
# f143
# f144
# f145
# f146
# f147
# f148
# f149
# f150
# f151
# f152
# f153
# f154
# f155
# f156
# f157
# f158
# f159
# f160
# f161
# f162
# f163
# f164
# f165
# f166
# f167
# f168
# f169
# f170
# f171
# f172
# f173
# f174
# f175
# f176
# f177
# f178
# f179
# f180
# f181
# f182
# f183
# f184
# f185
# f186
# f187
# f188
# f189
# f190
# f191
# f192
# f193
# f194
# f195
# f196
# f197
# f198
# f199
# f200
# f201
# f202
# f203
# f204
# f205
# f206
# f207
# f208
# f209
# f210
# f211
# f212
# f213
# f214
# f215
# f216
# f217
# f218
# f219
# f220
# f221
# f222
# f223
# f224
# f225
# f226
# f227
# f228
# f229
# f230
# f231
# f232
# f233
# f234
# f235
# f236
# f237
# f238
# f239
# f240
# f241
# f242
# f243
# f244
# f245
# f246
# f247
# f248
# f249
# f250
# f251
# f252
# f253
# f254
# f255
# f256
# f257
# f258
# f259
# f260
# f261
# f262
# f263
# f264
# f265
# f266
# f267
# f268
# f269
# f270
# f271
# f272
# f273
# f274
# f275
# f276
# f277
# f278
# f279
# f280
# f281
# f282
# f283
# f284
# f285
# f286
# f287
# f288
# f289
# f290
# f291
# f292
# f293
# f294
# f295
# f296
# f297
# ******************** 298 round ********************
# f1
# reverse 0/296
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-8b6c82cec300> in <module>()
#      12 sf.clf = lgb.LGBMClassifier(random_state=10, num_leaves =15, n_estimators=200, max_depth=5, learning_rate = 0.1, n_jobs=-1) #设定模型
#      13 sf.SetLogFile('record.log') #初始化日志文件
# ---> 14 sf.run(validation) #输入检验函数并开始运行
#
# /usr/local/lib/python3.5/dist-packages/MLFeatureSelection/FeatureSelection.py in run(self, validate)
#     490                                     )
#     491         try:
# --> 492             a.select()
#     493         finally:
#     494             with open(self._logfile, 'a') as f:
#
# /usr/local/lib/python3.5/dist-packages/MLFeatureSelection/FeatureSelection.py in select(self)
#     107             # greedy: forward + backward + Simulated Annealing
#     108             if self.Process[0]:
# --> 109                 self._Greedy()
#     110             self._ScoreUpdate()
#     111             self._greedyscore = self.bestscore
#
# /usr/local/lib/python3.5/dist-packages/MLFeatureSelection/FeatureSelection.py in _Greedy(self)
#     224                 print(i)
#     225                 print('reverse {}/{}'.format(sr,len(self._TemplUsedFeatures[:-1])))
# --> 226                 self._validation(deletecol, 'reverse', i, coetest = 0)
#     227             for i in self._TemplUsedFeatures:
#     228                 if i in self._PotentialAdd:
#
# /usr/local/lib/python3.5/dist-packages/MLFeatureSelection/FeatureSelection.py in _validation(self, selectcol, num, addfeature, coetest)
#     163         X, y = tempdf, tempdf[self._Label]
#     164         totaltest = self._validatefunction(X, y, selectcol,
# --> 165                                            self._clf, self._LossFunction) #, self._fit_params)
#     166         print('Mean loss: {}'.format(totaltest))
#     167         # only when the score improve, the program will record,
#
# <ipython-input-13-99ddef1bcfed> in validation(X, Y, features, clf, lossfunction)
#      17         X_train, X_test = X.ix[train_index,:][features], X.ix[test_index,:][features]
#      18         y_train, y_test = Y[train_index], Y[test_index]
# ---> 19         clf.fit(X_train, y_train)
#      20         totaltest.append(lossfunction(y_test, clf.predict(X_test)))
#      21     return np.mean(totaltest)
#
# /usr/local/lib/python3.5/dist-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     673                                         verbose=verbose, feature_name=feature_name,
#     674                                         categorical_feature=categorical_feature,
# --> 675                                         callbacks=callbacks)
#     676         return self
#     677
#
# /usr/local/lib/python3.5/dist-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     467                               verbose_eval=verbose, feature_name=feature_name,
#     468                               categorical_feature=categorical_feature,
# --> 469                               callbacks=callbacks)
#     470
#     471         if evals_result:
#
# /usr/local/lib/python3.5/dist-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     199                                     evaluation_result_list=None))
#     200
# --> 201         booster.update(fobj=fobj)
#     202
#     203         evaluation_result_list = []
#
# /usr/local/lib/python3.5/dist-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1522             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1523                 self.handle,
# -> 1524                 ctypes.byref(is_finished)))
#    1525             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1526             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
import lightgbm as lgb

sf = FS.Select(Sequence = True, Random = False, Cross = False)
sf.ImportDF(train_df, label ='Fraud') 
sf.ImportLossFunction(score, direction = 'ascend')
sf.InitialNonTrainableFeatures(atecml.data.NOT_FEATURE_COLUMNS) 
sf.InitialFeatures(predictors) 
sf.GenerateCol() 
sf.SetSample(1, samplemode = 1) 
sf.SetTimeLimit(720)
sf.clf = lgb.LGBMClassifier(random_state=10, num_leaves =50, n_estimators=1000, max_depth=10, learning_rate = 0.1, n_jobs=-1)
sf.SetLogFile('record.log') 
sf.run(validation)
